# %%
#from transformer import Encoder
from torch import nn,optim
from torch.nn.functional import cross_entropy,softmax, relu
from torch.utils.data import DataLoader
from torch.utils.data.dataloader import default_collate

import torch
import utils
import os
import pickle

# %%
import import_ipynb

# %%
Encoder = __import__('5_transformer').Encoder

# %%
class GPT(nn.Module):

    def __init__(self, model_dim, max_len, num_layer, num_head, n_vocab, lr, max_seg=3, drop_rate=0.2,padding_idx=0):
        super().__init__()
        self.padding_idx = padding_idx
        self.n_vocab = n_vocab
        self.max_len = max_len
        
        self.word_emb = nn.Embedding(n_vocab,model_dim)
        self.word_emb.weight.data.normal_(0,0.1)

        self.segment_emb = nn.Embedding(num_embeddings= max_seg, embedding_dim=model_dim)
        self.segment_emb.weight.data.normal_(0,0.1)
        self.position_emb = torch.empty(1,max_len,model_dim)
        nn.init.kaiming_normal_(self.position_emb,mode='fan_out', nonlinearity='relu')
        self.position_emb = nn.Parameter(self.position_emb)


        self.encoder = Encoder(n_head=num_head, emb_dim=model_dim, drop_rate=drop_rate, n_layer=num_layer)
        self.task_mlm = nn.Linear(in_features=model_dim, out_features=n_vocab)
        self.task_nsp = nn.Linear(in_features=model_dim*self.max_len, out_features=2)

        self.opt = optim.Adam(self.parameters(),lr)
    
    def forward(self,seqs, segs, training=False):
        embed = self.input_emb(seqs, segs)
        z = self.encoder(embed, training, mask = self.mask(seqs))   # [n, step, model_dim]
        mlm_logits = self.task_mlm(z)   # [n, step, n_vocab]
        nsp_logits = self.task_nsp(z.reshape(z.shape[0],-1))    # [n, n_cls]
        return mlm_logits, nsp_logits
    
    def step(self, seqs, segs, seqs_, nsp_labels):
        self.opt.zero_grad()
        mlm_logits, nsp_logits = self(seqs, segs, training=True)
        pred_loss = cross_entropy(mlm_logits.reshape(-1,self.n_vocab),seqs_.reshape(-1))
        nsp_loss = cross_entropy(nsp_logits,nsp_labels.reshape(-1))
        loss = pred_loss + 0.2 * nsp_loss
        loss.backward()
        self.opt.step()
        return loss.cpu().data.numpy(), mlm_logits
    
    def input_emb(self,seqs, segs):
        # device = next(self.parameters()).device
        # self.position_emb = self.position_emb.to(device)
        return self.word_emb(seqs) + self.segment_emb(segs) + self.position_emb
    
    def mask(self, seqs):
        device = next(self.parameters()).device
        batch_size, seq_len = seqs.shape
        mask = torch.triu(torch.ones((seq_len,seq_len), dtype=torch.long), diagonal=1).to(device)  # [seq_len ,seq_len]
        pad = torch.eq(seqs,self.padding_idx)   # [n, seq_len]
        mask = torch.where(pad[:,None,None,:],1,mask[None,None,:,:]).to(device)   # [n, 1, seq_len, seq_len]
        return mask>0   # [n, 1, seq_len, seq_len]
    
    @property
    def attentions(self):
        attentions = {
            "encoder": [l.mh.attention.cpu().data.numpy() for l in self.encoder.encoder_layers]
        }
        return attentions

# %%
def train():
    MODEL_DIM = 256
    N_LAYER = 4
    LEARNING_RATE = 1e-4
    dataset = utils.MRPCData("./MRPC",2000)
    print("num word: ",dataset.num_word)
    model = GPT(
        model_dim=MODEL_DIM, max_len=dataset.max_len-1, num_layer=N_LAYER, num_head=4, n_vocab=dataset.num_word,
        lr=LEARNING_RATE, max_seg=dataset.num_seg, drop_rate=0.2, padding_idx=dataset.pad_id
    )
    if torch.cuda.is_available():
        print("GPU train avaliable")
        device =torch.device("cuda")
        model = model.cuda()
    else:
        device = torch.device("cpu")
        model = model.cpu()
    
    loader = DataLoader(dataset,batch_size=32,shuffle=True)

    for epoch in range(100):
        for batch_idx, batch in enumerate(loader):
            seqs, segs,xlen,nsp_labels = batch
            seqs, segs,nsp_labels = seqs.type(torch.LongTensor).to(device), segs.type(torch.LongTensor).to(device),nsp_labels.to(device)
            # pred: [n, step, n_vocab]
            loss,pred = model.step(seqs=seqs[:,:-1], segs= segs[:,:-1], seqs_=seqs[:,1:], nsp_labels=nsp_labels)
            if batch_idx %100 == 0:
                pred = pred[0].cpu().data.numpy().argmax(axis = 1) # [step]
                print(
                    "Epoch: ",epoch,
                "|batch: ", batch_idx,
                "| loss: %.3f" % loss,
                "\n| tgt: ", " ".join([dataset.i2v[i] for i in seqs[0, 1:].cpu().data.numpy()[:xlen[0].sum()+1]]),
                "\n| prd: ", " ".join([dataset.i2v[i] for i in pred[:xlen[0].sum()+1]]),
                )
#     os.makedirs("./visual/models/gpt",exist_ok=True)
#     torch.save(model.state_dict(),"./visual/models/gpt/model.pth")
#     export_attention(model,device,dataset)

# %%
def export_attention(model,device,data,name="gpt"):
    model.load_state_dict(torch.load("./visual/models/gpt/model.pth",map_location=device))
    seqs, segs,xlen,nsp_labels = data[:32]
    seqs, segs,xlen,nsp_labels = torch.from_numpy(seqs),torch.from_numpy(segs),torch.from_numpy(xlen),torch.from_numpy(nsp_labels)
    seqs, segs,nsp_labels = seqs.type(torch.LongTensor).to(device), segs.type(torch.LongTensor).to(device),nsp_labels.to(device)
    model(seqs[:,:-1],segs[:,:-1],False)
    seqs = seqs.cpu().data.numpy()
    data = {"src": [[data.i2v[i] for i in seqs[j]] for j in range(len(seqs))], "attentions": model.attentions}
    path = "./visual/tmp/%s_attention_matrix.pkl" % name
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, "wb") as f:
        pickle.dump(data, f)

# %%
if __name__ == "__main__":
    train()
# Out:
# num word:  12880
# GPU train avaliable
# Epoch:  0 |batch:  0 | loss: 10.043
# | tgt:  myanmar 's pro-democracy leader aung san suu kyi will return home late friday but will remain in detention after recovering from surgery at a yangon hospital , her personal physician said . <SEP> myanmar 's pro-democracy leader aung san suu kyi will be kept under house arrest following her release from a hospital where she underwent surgery , her personal physician said friday .
# | prd:  leighton structure jennette foolish tightness hit influential member wants asphyxiating pingeon dialogue district aboriginal particular security ash twin gillian <NUM>--available allegiant foolish communist awareness barnett losyukov losyukov radical addresses accounted multimillionaire significantly realized floors airline would-be accountable bitter pioneer nashville myanmar country village dallas-based village bodyguards movie gbi interfere sia biological gbi desperate keywords mclean preposterous toured dirk celebration addresses myanmar water rohtang kuby
# Epoch:  1 |batch:  0 | loss: 5.557
# | tgt:  the attack on the al-rashid hotel , during the visit of deputy defence secretary paul wolfowitz underscores the nature of the problem . <SEP> the attack on the rashid hotel on sunday , during the visit of the deputy secretary of defense , paul d. wolfowitz , underscores the nature of the problem .
# | prd:  the the the the the the the the the the the the the , the , , <SEP> the the the the the <SEP> <PAD> , <PAD> the , the , <PAD> the the , <PAD> <PAD> <PAD> the the <PAD> <PAD> <PAD> <PAD> , <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Epoch:  2 |batch:  0 | loss: 4.499
# | tgt:  <quote> i think it should have been released years ago , <quote> said brian rohrbough , whose son , daniel , was killed at columbine . <SEP> brian rohrbough , whose son , daniel , was killed at columbine , said the tape raises disturbing issues .
# | prd:  the the the the the , the the the , , the the the the the the the the the the the , the , the <SEP> <PAD> the , the the , the , the the , , , the , , , , , the
# Epoch:  3 |batch:  0 | loss: 4.312
# | tgt:  hill , <NUM> , would be the first person executed for killing an abortion doctor . <SEP> on wednesday , hill is scheduled to become the first person executed for murdering an abortion doctor .
# | prd:  the the the , the the the the , , the , , . , the <SEP> the the . the , , , the the , , . . , the , . .
# Epoch:  4 |batch:  0 | loss: 3.829
# | tgt:  a west knoxville restaurant has reported several cases of hepatitis a to the knox county health department . <SEP> the news has caused a rush of people to the knox county health department to get vaccinated .
# | prd:  the the , the , the . the , the . . the . . , . . <SEP> the the , the , , , the . the the , the , . the . .
# Epoch:  5 |batch:  0 | loss: 4.534
# | tgt:  directed by jonathan lynn from a script by elizabeth hunter and saladin k. patterson . <SEP> whole nine yards , <quote> and written by first-time screenwriters elizabeth hunter and saladin k. patterson .
# | prd:  the the the <NUM> , the <NUM> <NUM> the <NUM> , <NUM> , , <NUM> <SEP> the , the , the <SEP> the , , . the the . <NUM> . , .
# Epoch:  6 |batch:  0 | loss: 3.880
# | tgt:  mr annan also warned the us should not use the war on terror as an excuse to suppress <quote> long-cherished freedoms <quote> . <SEP> annan warned that the dangers of extremism after september <NUM> should not be used as an excuse to suppress <quote> long-cherished <quote> freedoms .
# | prd:  the , , <NUM> , the <NUM> and the , <NUM> . the , the of . the . <SEP> . . <SEP> <SEP> the , , the <NUM> , the , the , percent . the the to the the . the . <SEP> . <SEP> ,
# Epoch:  7 |batch:  0 | loss: 3.818
# | tgt:  the ftc also said aol and compuserve failed to deliver timely rebates to consumers . <SEP> in a separate complaint , the ftc alleged that aol and compuserve failed to deliver timely $ <NUM> rebates to consumers .
# | prd:  the company the the the of the , , the <NUM> , the the . <SEP> the the was , the <quote> company the , the to the , . the . . <NUM> . . the .
# Epoch:  8 |batch:  0 | loss: 3.903
# | tgt:  neither military action nor large-scale bribery can solve the north korean problem , wolfowitz said . <SEP> indeed , wolfowitz admitted saturday that neither military action nor <quote> large scale bribery <quote> would solve the issue .
# | prd:  the the the , , , the the the first , , , <quote> , . <SEP> the , the , , , the the the in , <SEP> . . . <SEP> be the . .
# Epoch:  9 |batch:  0 | loss: 3.643
# | tgt:  and now it 's anything he wants to say , <quote> alesha badgley , stone county nursing and rehabilitation center social director , said this week . <SEP> and now it 's anything he wants to say , <quote> confirmed stone county nursing and rehabilitation center social director alesha badgley .
# | prd:  the the <NUM> to <NUM> to said to the to <quote> <SEP> , , <quote> of . <quote> the to , . . <quote> . . . <SEP> the the , was a , said , the , <quote> <SEP> , of , <quote> the to , . of and .
# Epoch:  10 |batch:  0 | loss: 3.499
# | tgt:  westfield , which owns galleria in morley , also will continue discussions about the other co-owned centres such as knox city in melbourne , half-owned by deutsche bank . <SEP> westfield also will continue discussions over the other co-owned centres , such as knox city in melbourne , where deutsche bank owns a <NUM> per cent stake .
# | prd:  the , the , <NUM> , the , the , be , , <NUM> company , , . . a . , the . <quote> . the . . <SEP> the , , be , , the first the , the the , a , , the , and a , , to statement . . . .
# Epoch:  11 |batch:  0 | loss: 3.589
# | tgt:  with these assets , funny cide has a solid chance to become the first triple crown winner since affirmed in <NUM> . <SEP> funny cide is looking to become horse racing 's first triple crown winner in a generation .
# | prd:  the the , , the to , been statement <NUM> to the the company <NUM> the . . the the the . <SEP> the <NUM> , a , <NUM> the to of <NUM> <NUM> the of of the <NUM> .
# Epoch:  12 |batch:  0 | loss: 3.561
# | tgt:  one , fort carson-based sgt. ernest bucklew , <NUM> , was on his way home to attend his mother 's funeral in pennsylvania , relatives said . <SEP> sgt. ernest bucklew , <NUM> , was coming home from iraq to bury his mother in pennsylvania .
# | prd:  the of the , <NUM> the the , the percent or <NUM> the wife , , <NUM> . wife , <NUM> of the . to . . <SEP> the <NUM> <NUM> , <NUM> percent <NUM> <NUM> , , <NUM> , <NUM> <NUM> wife , the ,
# Epoch:  13 |batch:  0 | loss: 3.269
# | tgt:  if convicted , ciobanu could face up to <NUM> years in prison based on new laws in romania designed to prosecute cybercrime , softwin said . <SEP> ciobanu could face up to <NUM> years in prison under a new law in romania , according to bitdefender 's web site .
# | prd:  the the , the , be the <NUM> the percent in the , on the york in the , to <NUM> . , or . . <SEP> the to be the to <NUM> percent in the , the year york , <NUM> , or to <NUM> , <NUM> a ,
# Epoch:  14 |batch:  0 | loss: 3.203
# | tgt:  big blue says the sec calls the action a fact-finding investigation and has not reached any conclusions related to this matter . <SEP> the sec specifically advised ibm that this is a fact-finding investigation and that it has not reached any conclusions related to this matter .
# | prd:  the was <NUM> the company , , company in statement , , a been the the have the to the year . <SEP> the company , of to , the year a statement , in the the was been to to to the to the year .
# Epoch:  15 |batch:  0 | loss: 3.392
# | tgt:  with claritin 's decline , schering-plough 's best-selling products now are two drugs used together to treat hepatitis c , the antiviral pill ribavirin and an interferon medicine called peg-intron . <SEP> with claritin 's decline , schering-plough 's best-selling products are now antiviral drug ribavirin and an interferon medicine called peg-intron -- two drugs used together to treat hepatitis c.
# | prd:  the the , office , the 's <NUM> , , , the years . to . the a to . the united 's . . other estimated . . the . <SEP> <quote> the , office , the 's office , in to , the , and the estimated and to the . the . . to . be to .
# Epoch:  16 |batch:  0 | loss: 3.095
# Epoch:  23 |batch:  0 | loss: 2.592
# | tgt:  when biggs 's body was found , authorities had no leads until four months later , when a tipster said mallard talked about the incident at a party . <SEP> authorities had no leads in biggs ' death until four months later , when a tipster said mallard talked about the incident at a party .
# | prd:  the the 's office was a in the said been immediate in the . , , said the statement said . , to the united . a statement . <SEP> in said a immediate in a 's ' , the months , , a the statement said . , to a company . a statement .
# Epoch:  24 |batch:  0 | loss: 2.482
# | tgt:  we acted because we saw the existing evidence in a new light , through the prism of our experience on <NUM> september , <quote> rumsfeld said . <SEP> rather , the us acted because the administration saw <quote> existing evidence in a new light , through the prism of our experience on september <NUM> <quote> .
# | prd:  the have has the are the united <quote> in the statement york , <quote> the united of the . in the . , the said and . <SEP> <quote> , <quote> company the <quote> of new , the the <quote> , the statement york , <quote> the first of the of in the <NUM> . said
# Epoch:  25 |batch:  0 | loss: 2.658
# | tgt:  respondents who rated current business conditions as <quote> bad <quote> increased to <NUM> % from <NUM> % in june . <SEP> <quote> those rating present business conditions as ' bad ' increased to <NUM> per cent from <NUM> per cent , <quote> the report said .
# | prd:  the as was the year is with a he <quote> said to the percent , <NUM> . , the . <SEP> <quote> the who on in 's as a ' news ' to <NUM> , cent to <NUM> . cent to <quote> the company . .
# Epoch:  26 |batch:  0 | loss: 2.610
# | tgt:  <quote> as expected , second-quarter sales were weak driven by the combination of declining retail inventories and market-share losses , <quote> said robert a. eckert , chief executive . <SEP> <quote> as expected , second-quarter sales were weak driven by the combination of declining retail inventories and market-share losses , <quote> chief executive robert eckert said in a statement .
# | prd:  the the the to <quote> the would not , by the united of the issues <quote> and the into , <quote> said . <SEP> <SEP> , <quote> executive . <SEP> <quote> we the to <quote> and of not , by the united of the and <quote> and <quote> losses , <quote> said executive , <SEP> , . the statement .
# Epoch:  27 |batch:  0 | loss: 2.868
# | tgt:  an officer in the people 's liberation army selected from a pool of <NUM> , lt-col yang is the son of a teacher and an official at an agricultural firm . <SEP> a lieutenant colonel in the people 's liberation army , yang is the son of a teacher and an official at an agricultural firm .
# | prd:  the average , a two were <NUM> <NUM> , from the statement , the percent a yang , a u.s. of the year and a officer , <NUM> estimated in . <SEP> a new , in a new to president and , a , a new of the <NUM> and the estimated , a estimated of .
# Epoch:  28 |batch:  0 | loss: 2.580
# | tgt:  on sunday , the experts will perform the first simultaneous release of five whales from a single stranding incident in the united states . <SEP> today , the experts will perform the united states ' first simultaneous release of five whales from a single stranding incident .
# | prd:  the thursday , the united said be the united time of of the of from the statement . . . the united states . <SEP> the , the united was be the united states and ' call release of the years from the statement . incident .
# Epoch:  29 |batch:  0 | loss: 2.214
# | tgt:  a new variant of blaster also appeared wednesday and seemed to be spreading , according to antivirus companies . <SEP> the new variation of blaster was identified wednesday , according to antivirus company sophos .
# | prd:  the spokesman york of <NUM> was said in and other to be in , the to be . . <SEP> a new york of <NUM> was found and and a to be . , .
# Epoch:  30 |batch:  0 | loss: 2.272
# | prd:  the dow also in month , who rose , <NUM> , and was quattrone , <NUM> , and to <NUM> available in the . <SEP> the and rohrbough , <NUM> , and veritas quattrone , <NUM> , and said killed of his articles of <NUM> invoices to <NUM> with , and to <NUM> in in and .
# Epoch:  39 |batch:  0 | loss: 1.749
# | tgt:  lay had contended that turning over the documents would violate his fifth amendment right against self-incrimination . <SEP> lay had refused to turn over the papers , asserting his fifth amendment right against self-incrimination .
# | prd:  the had been that he the the death had be the wife amendment to , the . <SEP> he had been to be over the company , and his home amendment to . the .
# Epoch:  40 |batch:  0 | loss: 1.812
# | tgt:  the infineon case began in august <NUM> , when rambus accused infineon of patent infringement and infineon counter-sued rambus for breach of contract and fraud . <SEP> at that time , rambus accused infineon of patent infringement and infineon countersued rambus for breach of contract and fraud .
# | prd:  the technology-laced of is in <NUM> <NUM> , including she for of of <NUM> infringement and other counter-sued him for an of contract and other . <SEP> the <NUM> affects , <NUM> for of of saddam and and killed countersued an for breach of <NUM> and <NUM> .
# Epoch:  41 |batch:  0 | loss: 1.824
# | tgt:  for the second year in a row , rises in hospital costs accounted for much of the inflation , accounting for <NUM> percent of the overall cost increase . <SEP> for the second year in a row , rises in hospital costs dominated the increase , accounting for <NUM> percent of the overall cost spiral .
# | prd:  the the first quarter after a statement , including in the the for for the of the company , but for <NUM> . of the company cost of . <SEP> the the first quarter , the statement , rises in the the up the company , the for the percent of the new package of .
# Epoch:  42 |batch:  0 | loss: 1.682
# | tgt:  <quote> they are trying to turn him into a martyr , <quote> said vicki saporta , president of the national abortion federation , which tracks abortion-related violence . <SEP> <quote> we need to take these threats seriously , <quote> said vicki saporta , president of the national abortion federation .
# | prd:  the i are being to do him , the meeting , <quote> he he saporta , said of the united 's federation , the is abortion-related . . <SEP> <quote> i are to make over despicable - , <quote> said he saporta , <quote> of the national gun-ownership federation ,
# Epoch:  43 |batch:  0 | loss: 1.723
# | tgt:  <quote> this man gambled with our lives and we , the passengers , lost , <quote> said andres rivera jr . , who was also on the bus . <SEP> <quote> this man gambled with our lives and we , the passengers , lost , <quote> said passenger andres rivera jr . , whose <NUM>-year-old niece , jazmine santiago , was killed .
# | prd:  the the is , with the capacity and chief , <quote> united , <quote> , <quote> said dr. rivera , . , <quote> was not at the world . <SEP> <quote> we terrible gambled with the of and we , we killers , we , <quote> said the manifests rivera jr . , <quote> and , , <quote> santiago , said killed .
# Epoch:  44 |batch:  0 | loss: 1.571
# | tgt:  with the economy sluggish , producers have had a tough time trying to raise prices . <SEP> economists said the report on wholesale prices showed producers were having a tough time trying to raise prices .
# | prd:  the the <NUM> was , the were been a tribune time <NUM> to comment <NUM> . <SEP> <NUM> said the <NUM> shows friday prices on edwards were a a 1,700-square-mile time to to close <NUM> .
# Epoch:  45 |batch:  0 | loss: 1.497
# | tgt:  they said : â we believe that the time has come for legislation to make public places smoke-free . <SEP> <quote> the time has come to make public places smoke-free , <quote> they wrote in a letter to the times newspaper .
# | prd:  the said the <quote> we have that the case has been from the to the public from smoke-free . <SEP> they the attack has not to the no is smoke-free , <quote> said said in the statement to the government . .
# Epoch:  46 |batch:  0 | loss: 1.462
# | tgt:  american has laid off <NUM> of its missouri employees since dec. <NUM> , according to driskill . <SEP> since october <NUM> , american has laid off <NUM> flight attendants , according to george price , a union spokesman .
# | prd:  the masters been off <NUM> of the customer . . the <NUM> , according to the . <SEP> since <NUM> <NUM> , the has been off <NUM> million attendants , the to the scalise , according share . .
# Epoch:  47 |batch:  0 | loss: 1.340
# | tgt:  it was developed with consultation from more than <NUM> leaders in academia , industry , government and the public . <SEP> the plan , called the nih roadmap , was developed over <NUM> months with help from more than <NUM> consultants in industry and academia .
# | prd:  the also the over consultation from the than <NUM> percent in and , and and and and the war . <SEP> the plan , was the other roadmap , was the over <NUM> years and more and the than <NUM> and in the and other .
# Epoch:  48 |batch:  0 | loss: 1.386
# | tgt:  baer said he had concluded that lawyers for the two victims <quote> have shown , albeit barely ... that iraq provided material support to bin laden and al-qaeda <quote> . <SEP> judge harold baer concluded wednesday that lawyers for the two victims <quote> have shown , albeit barely ... that iraq provided material support to bin laden and al-qaida . <quote>
# | prd:  the said he would no that he for the the years <quote> he been , <quote> barely ... that they 's material support to be laden and exchange <quote> . <SEP> <quote> 's baer that that that the for the two years <quote> this been , <quote> barely ... the he 's material support to him laden and secular . <quote>
# Epoch:  49 |batch:  0 | loss: 1.308
# | tgt:  <quote> we 've put a lot of effort and energy into improving our patching progress , probably later than we should have . <SEP> <quote> we have put a lot of energy into patching , later than we should have , <quote> he said .
# | prd:  the we 're destroyed a lot of energy and we secretary our our patching , , <quote> not , a should have . <SEP> <quote> we are been a lot of we and our , we , we have have , <quote> he said .
# Epoch:  50 |batch:  0 | loss: 1.277
# | tgt:  his dissent was joined by chief justice william h. rehnquist and justice clarence thomas . <SEP> chief justice william h. rehnquist and justices antonin scalia and clarence thomas dissented .
# | prd:  <quote> decision was joined by chief justice william h. rehnquist and justice clarence thomas . <SEP> his justice william h. rehnquist and justices antonin scalia and justices thomas dissented .
# Epoch:  51 |batch:  0 | loss: 1.208
# | tgt:  peoplesoft also said its board had officially rejected oracle 's offer . <SEP> thursday morning , peoplesoft 's board rejected the oracle takeover offer .
# | prd:  the has said its first has been declared its 's new . <SEP> the at , who 's also elected the new takeover would .
# Epoch:  52 |batch:  0 | loss: 1.136
# | tgt:  she appeared in federal court there monday and was expected to be transferred to houston in two weeks . <SEP> holloway surrendered in cleveland on friday and was expected to be transferred to houston in two weeks .
# | prd:  the said in the court of were and was no to be transferred to be in the years . <SEP> she surrendered in federal on the and was in to be used to be in prison weeks .
# Epoch:  53 |batch:  0 | loss: 1.184
# | tgt:  it can store more than a gigabyte of information equivalent to around <NUM> hours of music in one cubic centimetre . <SEP> and it can store more than a gigabyte of information - equivalent to <NUM> high quality images or around <NUM> hours of music - in just one cubic centimetre .
# | prd:  the was be more than a gigabyte of of from to <NUM> <NUM> percent of of in the cubic centimetre . <SEP> it it easier be more than a gigabyte of that from news to <NUM> a of images or <NUM> <NUM> percent of music and in a hours cubic centimetre .
# Epoch:  54 |batch:  0 | loss: 1.186
# | tgt:  sco has also alleged that the generic linux kernel contains code which is from its unix property . <SEP> sco claims that the linux kernel holds unix intellectual property owned by sco .
# | prd:  the has also features that the first linux kernel is code which is expected the flawed property . <SEP> it has that the court kernel holds unix intellectual property at by the .
# Epoch:  55 |batch:  0 | loss: 1.042
# | tgt:  white house officials say iran has one last chance to comply with iaea inspection demands . <SEP> a white house spokesman added that iran had <quote> one last chance <quote> to comply with its disarmament obligations .
# | prd:  the house officials could they has a its year to make with evidence inspection demands . <SEP> a federal house officials for that two has not one person month <quote> to comply with evidence disarmament obligations .
# Epoch:  56 |batch:  0 | loss: 1.048
# | tgt:  microsoft , which acquired virtual pc from connectix in february , said a fix for the problem is not around the corner . <SEP> virtual pc , which microsoft acquired from connectix corp. in february , will not run on the g5 , the company said .
# | prd:  the on the is virtual pc from connectix in february , said a spokesman for the past could not the the company . <SEP> prosecutors pc , which it acquired from connectix corp. in iraq , the not seen on the g5 , the company said .
# Epoch:  57 |batch:  0 | loss: 0.987
# | tgt:  the industry censor forbade the sexual innuendo contained in the play and would not allow the characters to sleep together . <SEP> the industry censor forbade the sexual innuendo of the play and would not allow ewell 's character to sleep with monroe 's .
# | prd:  the dow censor forbade the case innuendo contained in the play and is not related the characters to begin together . <SEP> the state censor forbade the state innuendo of the play and would not immediately ewell 's character to sleep with monroe 's .
# Epoch:  58 |batch:  0 | loss: 1.031
# | tgt:  <quote> for us , that doesn 't make a difference - the sexual orientation , <quote> archbishop tutu said in the black urban centre of soweto . <SEP> <quote> for us that doesn 't make a difference , the sexual orientation , <quote> tutu told reuters television in south africa 's sprawling soweto township .
# | prd:  the i me , an we 't a a lot - the us orientation , <quote> archbishop tutu said in the united urban centre of soweto . <SEP> <quote> for the that ain 't be a statement , the us orientation , <quote> tutu told reporters ' in a africa 's sprawling soweto township .
# Epoch:  59 |batch:  0 | loss: 1.011
# | tgt:  <quote> i stand <NUM> percent by it , and i think our intelligence services gave us the correct information at the time . <quote> <SEP> i stand <NUM> percent by it , and i think that our intelligence services gave us the correct intelligence and information at the time , <quote> blair said .
# | prd:  the the think <NUM> percent of the , <quote> we think that capacity services gave us the new some at the world . <SEP> <SEP> <quote> 'm <NUM> percent by the , <quote> i think that the intelligence and are us the us some and i from the us , <quote> he said .
# Epoch:  60 |batch:  0 | loss: 0.934
# | tgt:  nine traffic deaths were blamed on the storm in north carolina , virginia , maryland , pennsylvania and washington . <SEP> at least <NUM> deaths have been blamed on the storm , <NUM> of them in virginia .
# | prd:  the years deaths were killed on the storm in prison korea , pennsylvania , <NUM> , pennsylvania . germany . <SEP> north least <NUM> was were been blamed on the murder , <NUM> and them in the .
# Epoch:  61 |batch:  0 | loss: 0.859
# | tgt:  he was released on $ <NUM>-million bail and immediately returned to las vegas , where he had been filming a video . <SEP> after posting $ <NUM> million bail , jackson flew to las vegas , where he had been working on a video .
# | prd:  the linda perry has said that while he opposes gambling expansion , he would be reluctant to veto continuation of the lottery commission . <SEP> gov. rick perry opposes expansion of gambling but has said he would be <quote> hard-pressed <quote> to veto the lottery sunset bill .
# Epoch:  85 |batch:  0 | loss: 0.342
# | tgt:  sse ceo marchant said he would sell on midlands ' power generation assets in turkey and pakistan to fellow british utility international power plc ipr.l for <NUM> million pounds . <SEP> after the deal sse will sell on midlands 's power generation assets in turkey and pakistan to fellow uk utility international power plc for <NUM> million pounds .
# | prd:  the ceo marchant said he would sell on midlands ' power generation . in turkey and pakistan to fellow british utility international power plc ipr.l for <NUM> million pounds . <SEP> after the contentions sse will sell on midlands 's power generation assets in turkey and pakistan to fellow uk utility international power plc for <NUM> million pounds .
# Epoch:  86 |batch:  0 | loss: 0.333
# | tgt:  the companies also announced plans to collaborate on the design for future generations of memory technologies . <SEP> the two groups said they would collaborate on the design of future memory technologies .
# | prd:  the new said could plans to collaborate on the design for future generations of memory technologies . <SEP> the two groups said they would collaborate on the design of future memory technologies .
# Epoch:  87 |batch:  0 | loss: 0.323
# | tgt:  chad kolton , emergency management spokesman with the department of homeland security , said the government is open to new technologies and methods to communicate more quickly and efficiently . <SEP> chad kolton , emergency management spokesman with the department of homeland security , said the government is open to new ways to communicate .
# | prd:  the kolton , emergency management spokesman with the department of homeland security , said the government is open to new technologies and methods to communicate more quickly and efficiently . <SEP> chad kolton , emergency management spokesman with the government of homeland security , said the government is open to new ways to communicate .
# Epoch:  88 |batch:  0 | loss: 0.324
# | tgt:  some <NUM> prisoners from <NUM> countries , including canada , are held , many captured during the war against in afghanistan the al-qaida network . <SEP> some <NUM> prisoners from <NUM> countries are being held at the naval base at guantanamo bay , many captured during the war against al qaeda in afghanistan .
# | prd:  the <NUM> customers from <NUM> countries , including the , are held , many captured during the war against in afghanistan the war network . <SEP> some <NUM> prisoners from <NUM> countries are being held at the naval base at guantanamo bay , many captured during the war against terrorism qaeda in afghanistan .
# Epoch:  89 |batch:  0 | loss: 0.292
# | tgt:  that ought to be the standard â not how many people sign up , <quote> he said . <SEP> <quote> that ought to be the standard , not how many people actually signed up , <quote> mr. rule told the judge .
# | prd:  the ought to be the standard â not how many people sign up , <quote> he said . <SEP> <quote> that ought to be the standard , not how many people actually signed up , <quote> mr. rule told the past .
# Epoch:  90 |batch:  0 | loss: 0.300
# | tgt:  available july <NUM> , the software supports the solaris , ibm aix , red hat linux and windows operating systems . <SEP> the opforce product currently works with solaris , aix , red hat linux and windows servers .
# | prd:  the july <NUM> , the nasdaq supports the solaris , ibm aix , red hat linux and windows operating systems . <SEP> the opforce product currently works with solaris , aix , red hat linux and windows servers .
# Epoch:  91 |batch:  0 | loss: 0.264
# | tgt:  rudder was most recently senior vice president for the developer & platform evangelism business . <SEP> senior vice president eric rudder , formerly head of the developer and platform evangelism unit , will lead the new entity .
# | prd:  the was most recently senior vice president for the developer & platform evangelism business . <SEP> senior vice president eric rudder , formerly head of the developer and platform evangelism unit , will lead the new entity .
