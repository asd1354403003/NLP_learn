# %%
from torch import nn
import torch
import numpy as np
import utils
from torch.utils.data import DataLoader
from torch.nn.functional import cross_entropy,softmax

# %%
class Seq2Seq(nn.Module):
    def __init__(self,enc_v_dim, dec_v_dim, emb_dim, units, max_pred_len, start_token, end_token):
        super().__init__()
        self.units = units
        self.dec_v_dim = dec_v_dim

        # encoder
        self.enc_embeddings = nn.Embedding(enc_v_dim,emb_dim)
        self.enc_embeddings.weight.data.normal_(0,0.1)
        self.encoder = nn.LSTM(emb_dim,units,1,batch_first=True)

        # decoder
        self.dec_embeddings = nn.Embedding(dec_v_dim,emb_dim)
        self.attn = nn.Linear(units,units)
        self.decoder_cell = nn.LSTMCell(emb_dim,units)
        self.decoder_dense = nn.Linear(units*2,dec_v_dim)

        self.opt = torch.optim.Adam(self.parameters(),lr=0.001)
        self.max_pred_len = max_pred_len
        self.start_token = start_token
        self.end_token = end_token
    
    def encode(self,x):
        embedded = self.enc_embeddings(x)   # [n, step, emb]
        hidden = (torch.zeros(1,x.shape[0],self.units),torch.zeros(1,x.shape[0],self.units))
        o,(h,c) = self.encoder(embedded,hidden) # [n, step, units], [num_layers * num_directions, n, units]
        return o,h,c
    
    def inference(self,x,return_align=False):
        self.eval()
        o,hx,cx = self.encode(x)    # [n, step, units], [num_layers * num_directions, n, units] * 2
        hx,cx = hx[0],cx[0]         # [n, units]
        start = torch.ones(x.shape[0],1)    # [n, 1]
        start[:,0] = torch.tensor(self.start_token)
        start= start.type(torch.LongTensor)
        dec_emb_in = self.dec_embeddings(start) # [n, 1, emb_dim]
        dec_emb_in = dec_emb_in.permute(1,0,2)  # [1, n, emb_dim]
        dec_in = dec_emb_in[0]                  # [n, emb_dim]
        output = []
        for i in range(self.max_pred_len):
            attn_prod = torch.matmul(self.attn(hx.unsqueeze(1)),o.permute(0,2,1)) # [n, 1, step]
            att_weight = softmax(attn_prod, dim=2)  # [n, 1, step]
            context = torch.matmul(att_weight,o)    # [n, 1, units]
            # attn_prod = torch.matmul(self.attn(o),hx.unsqueeze(2))  # [n, step, 1]
            # attn_weight = softmax(attn_prod,dim=1)                  # [n, step, 1]
            # context = torch.matmul(o.permute(0,2,1),attn_weight)    # [n, units, 1]
            hx, cx = self.decoder_cell(dec_in, (hx, cx))
            hc = torch.cat([context.squeeze(1),hx],dim=1)           # [n, units *2]
            # hc = torch.cat([context.squeeze(2),hx],dim=1)           # [n, units *2]
            result = self.decoder_dense(hc)
            result = result.argmax(dim=1).view(-1,1)
            dec_in=self.dec_embeddings(result).permute(1,0,2)[0]
            output.append(result)
        output = torch.stack(output,dim=0)
        self.train()

        return output.permute(1,0,2).view(-1,self.max_pred_len)
    
    def train_logit(self,x,y):
        o,hx,cx = self.encode(x)    # [n, step, units], [num_layers * num_directions, n, units] * 2
        hx,cx = hx[0],cx[0]         # [n, units]
        dec_in = y[:,:-1]           # [n, step]
        dec_emb_in = self.dec_embeddings(dec_in)    # [n, step, emb_dim]
        dec_emb_in = dec_emb_in.permute(1,0,2)      # [step, n, emb_dim]
        output = []
        for i in range(dec_emb_in.shape[0]):
            # General Attention:
            # score(ht,hs) = (ht^T)(Wa)hs
            # hs is the output from encoder
            # ht is the previous hidden state from decoder
            # self.attn(o): [n, step, units]
            attn_prod = torch.matmul(self.attn(hx.unsqueeze(1)),o.permute(0,2,1)) # [n, 1, step]
            att_weight = softmax(attn_prod, dim=2)  # [n, 1, step]
            context = torch.matmul(att_weight,o)    # [n, 1, units]
            # attn_prod = torch.matmul(self.attn(o),hx.unsqueeze(2))  # [n, step, 1]
            # attn_weight = softmax(attn_prod,dim=1)                  # [n, step, 1]
            # context = torch.matmul(o.permute(0,2,1),attn_weight)    # [n, units, 1]
            hx, cx = self.decoder_cell(dec_emb_in[i], (hx, cx))     # [n, units]
            hc = torch.cat([context.squeeze(1),hx],dim=1)           # [n, units *2]
            # hc = torch.cat([context.squeeze(2),hx],dim=1)           # [n, units *2]
            result = self.decoder_dense(hc)                              # [n, dec_v_dim]
            output.append(result)
        output = torch.stack(output,dim=0)  # [step, n, dec_v_dim]
        return output.permute(1,0,2)        # [n, step, dec_v_dim]
    
    def step(self,x,y):
        self.opt.zero_grad()
        batch_size = x.shape[0]
        logit = self.train_logit(x,y)    
        dec_out = y[:,1:]
        loss = cross_entropy(logit.reshape(-1,self.dec_v_dim),dec_out.reshape(-1))
        loss.backward()
        self.opt.step()
        return loss.detach().numpy()

# %%
def train():
    dataset = utils.DateData(4000)
    print("Chinese time order: yy/mm/dd ",dataset.date_cn[:3],"\nEnglish time order: dd/M/yyyy", dataset.date_en[:3])
    print("Vocabularies: ", dataset.vocab)
    print(f"x index sample:  \n{dataset.idx2str(dataset.x[0])}\n{dataset.x[0]}",
    f"\ny index sample:  \n{dataset.idx2str(dataset.y[0])}\n{dataset.y[0]}")
    loader = DataLoader(dataset,batch_size=32,shuffle=True)
    model = Seq2Seq(dataset.num_word,dataset.num_word,emb_dim=16,units=32,max_pred_len=11,start_token=dataset.start_token,end_token=dataset.end_token)
    for i in range(100):
        for batch_idx , batch in enumerate(loader):
            bx, by, decoder_len = batch
            loss = model.step(bx.long(),by.long())
            if batch_idx % 70 == 0:
                target = dataset.idx2str(by[0, 1:-1].data.numpy())
                pred = model.inference(bx[0:1])
                res = dataset.idx2str(pred[0].data.numpy())
                src = dataset.idx2str(bx[0].data.numpy())
                print(
                    "Epoch: ",i,
                    "| t: ", batch_idx,
                    "| loss: %.3f" % loss,
                    "| input: ", src,
                    "| target: ", target,
                    "| inference: ", res,
                )

# %%
if __name__ == "__main__":
    train()
# Out:
# Chinese time order: yy/mm/dd  ['31-04-25', '04-07-17', '33-06-06']
# English time order: dd/M/yyyy ['25/Apr/2031', '17/Jul/2004', '06/Jun/2033']
# Vocabularies:  {'3', 'Mar', 'Dec', '1', '7', 'Feb', 'Jul', '-', 'Nov', '9', '<EOS>', '/', '<PAD>', '5', 'Jun', 'Apr', '6', '<GO>', '4', '0', 'Oct', '2', 'Jan', '8', 'Sep', 'May', 'Aug'}
# x index sample:
# 31-04-25
# [6 4 1 3 7 1 5 8]
# y index sample:
# <GO>25/Apr/2031<EOS>
# [14  5  8  2 15  2  5  3  6  4 13]
# Epoch:  0 | t:  0 | loss: 3.305 | input:  97-06-26 | target:  26/Jun/1997 | inference:  Apr0000000000
# Epoch:  0 | t:  70 | loss: 2.429 | input:  24-07-17 | target:  17/Jul/2024 | inference:  20/////////
# Epoch:  1 | t:  0 | loss: 1.806 | input:  20-07-22 | target:  22/Jul/2020 | inference:  20////200<EOS>
# Epoch:  1 | t:  70 | loss: 1.257 | input:  93-02-08 | target:  08/Feb/1993 | inference:  1///2002<EOS>
# Epoch:  2 | t:  0 | loss: 1.116 | input:  81-07-23 | target:  23/Jul/1981 | inference:  11//2019<EOS>
# Epoch:  2 | t:  70 | loss: 1.043 | input:  89-07-26 | target:  26/Jul/1989 | inference:  11/Jan/2001<EOS>
# Epoch:  3 | t:  0 | loss: 1.017 | input:  90-01-24 | target:  24/Jan/1990 | inference:  21/Jan/2003<EOS>
# Epoch:  3 | t:  70 | loss: 0.979 | input:  12-10-04 | target:  04/Oct/2012 | inference:  23/Jul/2023<EOS>
# Epoch:  4 | t:  0 | loss: 0.946 | input:  22-10-15 | target:  15/Oct/2022 | inference:  04/Mar/2023<EOS>
# Epoch:  4 | t:  70 | loss: 0.892 | input:  15-10-29 | target:  29/Oct/2015 | inference:  22/Oct/2011<EOS>
# Epoch:  5 | t:  0 | loss: 0.873 | input:  78-10-21 | target:  21/Oct/1978 | inference:  11/Jan/1981<EOS>
# Epoch:  5 | t:  70 | loss: 0.823 | input:  23-06-30 | target:  30/Jun/2023 | inference:  06/Mar/2022<EOS>
# Epoch:  6 | t:  0 | loss: 0.781 | input:  30-05-26 | target:  26/May/2030 | inference:  26/Jul/2007<EOS>
# Epoch:  6 | t:  70 | loss: 0.738 | input:  21-04-15 | target:  15/Apr/2021 | inference:  15/Mar/2024<EOS>
# Epoch:  7 | t:  0 | loss: 0.676 | input:  86-08-02 | target:  02/Aug/1986 | inference:  02/Dec/1989<EOS>
# Epoch:  7 | t:  70 | loss: 0.641 | input:  77-08-21 | target:  21/Aug/1977 | inference:  21/Jan/1981<EOS>
# Epoch:  8 | t:  0 | loss: 0.633 | input:  85-07-31 | target:  31/Jul/1985 | inference:  11/Dec/1981<EOS>
# Epoch:  8 | t:  70 | loss: 0.596 | input:  07-12-29 | target:  29/Dec/2007 | inference:  29/Dec/1992<EOS>
# Epoch:  9 | t:  0 | loss: 0.546 | input:  01-06-15 | target:  15/Jun/2001 | inference:  15/Mar/2008<EOS>
# Epoch:  9 | t:  70 | loss: 0.503 | input:  77-10-06 | target:  06/Oct/1977 | inference:  06/May/1981<EOS>
# Epoch:  44 | t:  0 | loss: 0.005 | input:  25-01-16 | target:  16/Jan/2025 | inference:  16/Jan/2025<EOS>
# Epoch:  44 | t:  70 | loss: 0.005 | input:  27-04-22 | target:  22/Apr/2027 | inference:  22/Apr/2027<EOS>
# Epoch:  45 | t:  0 | loss: 0.004 | input:  17-04-04 | target:  04/Apr/2017 | inference:  04/Apr/2017<EOS>
# Epoch:  45 | t:  70 | loss: 0.005 | input:  33-06-25 | target:  25/Jun/2033 | inference:  25/Jun/2033<EOS>
# Epoch:  46 | t:  0 | loss: 0.004 | input:  15-12-01 | target:  01/Dec/2015 | inference:  01/Dec/2015<EOS>
# Epoch:  46 | t:  70 | loss: 0.003 | input:  03-11-28 | target:  28/Nov/2003 | inference:  28/Nov/2003<EOS>
# Epoch:  47 | t:  0 | loss: 0.005 | input:  86-11-17 | target:  17/Nov/1986 | inference:  17/Nov/1986<EOS>
# Epoch:  47 | t:  70 | loss: 0.016 | input:  01-09-07 | target:  07/Sep/2001 | inference:  07/Sep/2001<EOS>
# Epoch:  48 | t:  0 | loss: 0.005 | input:  78-08-13 | target:  13/Aug/1978 | inference:  13/Aug/1978<EOS>
# Epoch:  48 | t:  70 | loss: 0.004 | input:  86-12-10 | target:  10/Dec/1986 | inference:  10/Dec/1986<EOS>
# Epoch:  49 | t:  0 | loss: 0.003 | input:  31-06-20 | target:  20/Jun/2031 | inference:  20/Jun/2031<EOS>
# Epoch:  49 | t:  70 | loss: 0.003 | input:  29-01-16 | target:  16/Jan/2029 | inference:  16/Jan/2029<EOS>
# Epoch:  50 | t:  0 | loss: 0.003 | input:  16-08-15 | target:  15/Aug/2016 | inference:  15/Aug/2016<EOS>
# Epoch:  50 | t:  70 | loss: 0.003 | input:  00-06-28 | target:  28/Jun/2000 | inference:  28/Jun/2000<EOS>
# Epoch:  51 | t:  0 | loss: 0.003 | input:  81-11-23 | target:  23/Nov/1981 | inference:  23/Nov/1981<EOS>
# Epoch:  51 | t:  70 | loss: 0.002 | input:  04-08-11 | target:  11/Aug/2004 | inference:  11/Aug/2004<EOS>
# Epoch:  52 | t:  0 | loss: 0.002 | input:  98-08-25 | target:  25/Aug/1998 | inference:  25/Aug/1998<EOS>
# Epoch:  52 | t:  70 | loss: 0.002 | input:  89-04-07 | target:  07/Apr/1989 | inference:  07/Apr/1989<EOS>
# Epoch:  53 | t:  0 | loss: 0.002 | input:  02-06-11 | target:  11/Jun/2002 | inference:  11/Jun/2002<EOS>
# Epoch:  53 | t:  70 | loss: 0.002 | input:  94-01-25 | target:  25/Jan/1994 | inference:  25/Jan/1994<EOS>
# Epoch:  54 | t:  0 | loss: 0.002 | input:  86-07-24 | target:  24/Jul/1986 | inference:  24/Jul/1986<EOS>
# Epoch:  54 | t:  70 | loss: 0.002 | input:  98-05-04 | target:  04/May/1998 | inference:  04/May/1998<EOS>
# Epoch:  55 | t:  0 | loss: 0.002 | input:  81-02-26 | target:  26/Feb/1981 | inference:  26/Feb/1981<EOS>
# Epoch:  55 | t:  70 | loss: 0.002 | input:  28-04-30 | target:  30/Apr/2028 | inference:  30/Apr/2028<EOS>
# Epoch:  56 | t:  0 | loss: 0.002 | input:  01-10-20 | target:  20/Oct/2001 | inference:  20/Oct/2001<EOS>
# Epoch:  56 | t:  70 | loss: 0.002 | input:  04-06-26 | target:  26/Jun/2004 | inference:  26/Jun/2004<EOS>
# Epoch:  57 | t:  0 | loss: 0.002 | input:  32-03-08 | target:  08/Mar/2032 | inference:  08/Mar/2032<EOS>
# Epoch:  57 | t:  70 | loss: 0.001 | input:  05-04-12 | target:  12/Apr/2005 | inference:  12/Apr/2005<EOS>
# Epoch:  58 | t:  0 | loss: 0.001 | input:  18-01-02 | target:  02/Jan/2018 | inference:  02/Jan/2018<EOS>
# Epoch:  58 | t:  70 | loss: 0.001 | input:  28-12-18 | target:  18/Dec/2028 | inference:  18/Dec/2028<EOS>
# Epoch:  59 | t:  0 | loss: 0.001 | input:  83-07-15 | target:  15/Jul/1983 | inference:  15/Jul/1983<EOS>
# Epoch:  59 | t:  70 | loss: 0.001 | input:  80-02-10 | target:  10/Feb/1980 | inference:  10/Feb/1980<EOS>
# Epoch:  60 | t:  0 | loss: 0.001 | input:  01-11-16 | target:  16/Nov/2001 | inference:  16/Nov/2001<EOS>
# Epoch:  60 | t:  70 | loss: 0.001 | input:  30-12-05 | target:  05/Dec/2030 | inference:  05/Dec/2030<EOS>
# Epoch:  61 | t:  0 | loss: 0.001 | input:  28-09-13 | target:  13/Sep/2028 | inference:  13/Sep/2028<EOS>
# Epoch:  61 | t:  70 | loss: 0.001 | input:  32-12-08 | target:  08/Dec/2032 | inference:  08/Dec/2032<EOS>
# Epoch:  62 | t:  0 | loss: 0.001 | input:  16-05-22 | target:  22/May/2016 | inference:  22/May/2016<EOS>
# Epoch:  62 | t:  70 | loss: 0.001 | input:  90-11-05 | target:  05/Nov/1990 | inference:  05/Nov/1990<EOS>
# Epoch:  63 | t:  0 | loss: 0.001 | input:  87-04-13 | target:  13/Apr/1987 | inference:  13/Apr/1987<EOS>
# Epoch:  63 | t:  70 | loss: 0.001 | input:  77-07-04 | target:  04/Jul/1977 | inference:  04/Jul/1977<EOS>
# Epoch:  64 | t:  0 | loss: 0.001 | input:  07-10-11 | target:  11/Oct/2007 | inference:  11/Oct/2007<EOS>
# Epoch:  64 | t:  70 | loss: 0.001 | input:  95-12-01 | target:  01/Dec/1995 | inference:  01/Dec/1995<EOS>
# Epoch:  65 | t:  0 | loss: 0.001 | input:  97-02-09 | target:  09/Feb/1997 | inference:  09/Feb/1997<EOS>
# Epoch:  65 | t:  70 | loss: 0.001 | input:  92-11-13 | target:  13/Nov/1992 | inference:  13/Nov/1992<EOS>
# Epoch:  66 | t:  0 | loss: 0.001 | input:  31-10-24 | target:  24/Oct/2031 | inference:  24/Oct/2031<EOS>
# Epoch:  66 | t:  70 | loss: 0.001 | input:  28-01-12 | target:  12/Jan/2028 | inference:  12/Jan/2028<EOS>
# Epoch:  67 | t:  0 | loss: 0.001 | input:  91-02-14 | target:  14/Feb/1991 | inference:  14/Feb/1991<EOS>
# Epoch:  67 | t:  70 | loss: 0.001 | input:  95-03-05 | target:  05/Mar/1995 | inference:  05/Mar/1995<EOS>
# Epoch:  68 | t:  0 | loss: 0.001 | input:  06-05-15 | target:  15/May/2006 | inference:  15/May/2006<EOS>
# Epoch:  68 | t:  70 | loss: 0.001 | input:  17-05-08 | target:  08/May/2017 | inference:  08/May/2017<EOS>
# Epoch:  69 | t:  0 | loss: 0.001 | input:  80-10-01 | target:  01/Oct/1980 | inference:  01/Oct/1980<EOS>
# Epoch:  69 | t:  70 | loss: 0.001 | input:  04-12-09 | target:  09/Dec/2004 | inference:  09/Dec/2004<EOS>
# Epoch:  70 | t:  0 | loss: 0.001 | input:  76-01-23 | target:  23/Jan/1976 | inference:  23/Jan/1976<EOS>
# Epoch:  70 | t:  70 | loss: 0.001 | input:  28-03-01 | target:  01/Mar/2028 | inference:  01/Mar/2028<EOS>
# Epoch:  71 | t:  0 | loss: 0.001 | input:  29-11-08 | target:  08/Nov/2029 | inference:  08/Nov/2029<EOS>
# Epoch:  71 | t:  70 | loss: 0.001 | input:  18-04-23 | target:  23/Apr/2018 | inference:  23/Apr/2018<EOS>
# Epoch:  72 | t:  0 | loss: 0.001 | input:  21-08-28 | target:  28/Aug/2021 | inference:  28/Aug/2021<EOS>
# Epoch:  72 | t:  70 | loss: 0.001 | input:  15-06-08 | target:  08/Jun/2015 | inference:  08/Jun/2015<EOS>
# Epoch:  73 | t:  0 | loss: 0.001 | input:  86-01-02 | target:  02/Jan/1986 | inference:  02/Jan/1986<EOS>
# Epoch:  73 | t:  70 | loss: 0.000 | input:  94-07-12 | target:  12/Jul/1994 | inference:  12/Jul/1994<EOS>
# Epoch:  74 | t:  0 | loss: 0.001 | input:  20-06-03 | target:  03/Jun/2020 | inference:  03/Jun/2020<EOS>
# Epoch:  74 | t:  70 | loss: 0.000 | input:  21-01-09 | target:  09/Jan/2021 | inference:  09/Jan/2021<EOS>
# Epoch:  75 | t:  0 | loss: 0.000 | input:  21-11-17 | target:  17/Nov/2021 | inference:  17/Nov/2021<EOS>
# Epoch:  75 | t:  70 | loss: 0.000 | input:  31-09-20 | target:  20/Sep/2031 | inference:  20/Sep/2031<EOS>
# Epoch:  76 | t:  0 | loss: 0.000 | input:  26-11-30 | target:  30/Nov/2026 | inference:  30/Nov/2026<EOS>
# Epoch:  76 | t:  70 | loss: 0.000 | input:  75-01-17 | target:  17/Jan/1975 | inference:  17/Jan/1975<EOS>
# Epoch:  77 | t:  0 | loss: 0.000 | input:  97-09-09 | target:  09/Sep/1997 | inference:  09/Sep/1997<EOS>
# Epoch:  77 | t:  70 | loss: 0.000 | input:  04-01-28 | target:  28/Jan/2004 | inference:  28/Jan/2004<EOS>
# Epoch:  78 | t:  0 | loss: 0.000 | input:  01-08-02 | target:  02/Aug/2001 | inference:  02/Aug/2001<EOS>
# Epoch:  78 | t:  70 | loss: 0.000 | input:  88-12-12 | target:  12/Dec/1988 | inference:  12/Dec/1988<EOS>
# Epoch:  79 | t:  0 | loss: 0.000 | input:  84-12-04 | target:  04/Dec/1984 | inference:  04/Dec/1984<EOS>
# Epoch:  79 | t:  70 | loss: 0.000 | input:  90-04-22 | target:  22/Apr/1990 | inference:  22/Apr/1990<EOS>
# Epoch:  80 | t:  0 | loss: 0.000 | input:  27-11-20 | target:  20/Nov/2027 | inference:  20/Nov/2027<EOS>
# Epoch:  80 | t:  70 | loss: 0.000 | input:  18-09-22 | target:  22/Sep/2018 | inference:  22/Sep/2018<EOS>
# Epoch:  81 | t:  0 | loss: 0.000 | input:  81-06-10 | target:  10/Jun/1981 | inference:  10/Jun/1981<EOS>
# Epoch:  81 | t:  70 | loss: 0.000 | input:  87-08-30 | target:  30/Aug/1987 | inference:  30/Aug/1987<EOS>
# Epoch:  82 | t:  0 | loss: 0.000 | input:  12-01-25 | target:  25/Jan/2012 | inference:  25/Jan/2012<EOS>
# Epoch:  82 | t:  70 | loss: 0.000 | input:  75-05-11 | target:  11/May/1975 | inference:  11/May/1975<EOS>
# Epoch:  83 | t:  0 | loss: 0.000 | input:  28-11-18 | target:  18/Nov/2028 | inference:  18/Nov/2028<EOS>
# Epoch:  83 | t:  70 | loss: 0.000 | input:  18-12-04 | target:  04/Dec/2018 | inference:  04/Dec/2018<EOS>
# Epoch:  84 | t:  0 | loss: 0.000 | input:  87-01-07 | target:  07/Jan/1987 | inference:  07/Jan/1987<EOS>
# Epoch:  84 | t:  70 | loss: 0.000 | input:  81-12-23 | target:  23/Dec/1981 | inference:  23/Dec/1981<EOS>
# Epoch:  85 | t:  0 | loss: 0.000 | input:  76-01-01 | target:  01/Jan/1976 | inference:  01/Jan/1976<EOS>
# Epoch:  85 | t:  70 | loss: 0.000 | input:  94-05-26 | target:  26/May/1994 | inference:  26/May/1994<EOS>
# Epoch:  86 | t:  0 | loss: 0.000 | input:  08-12-20 | target:  20/Dec/2008 | inference:  20/Dec/2008<EOS>
# Epoch:  86 | t:  70 | loss: 0.000 | input:  21-05-09 | target:  09/May/2021 | inference:  09/May/2021<EOS>
# Epoch:  87 | t:  0 | loss: 0.000 | input:  74-07-28 | target:  28/Jul/1974 | inference:  28/Jul/1974<EOS>
# Epoch:  87 | t:  70 | loss: 0.000 | input:  24-04-08 | target:  08/Apr/2024 | inference:  08/Apr/2024<EOS>
# Epoch:  88 | t:  0 | loss: 0.000 | input:  00-09-22 | target:  22/Sep/2000 | inference:  22/Sep/2000<EOS>
# Epoch:  88 | t:  70 | loss: 0.000 | input:  26-05-29 | target:  29/May/2026 | inference:  29/May/2026<EOS>
# Epoch:  89 | t:  0 | loss: 0.000 | input:  11-08-28 | target:  28/Aug/2011 | inference:  28/Aug/2011<EOS>
# Epoch:  89 | t:  70 | loss: 0.000 | input:  78-02-15 | target:  15/Feb/1978 | inference:  15/Feb/1978<EOS>
# Epoch:  90 | t:  0 | loss: 0.000 | input:  78-02-16 | target:  16/Feb/1978 | inference:  16/Feb/1978<EOS>
# Epoch:  90 | t:  70 | loss: 0.000 | input:  13-12-29 | target:  29/Dec/2013 | inference:  29/Dec/2013<EOS>
# Epoch:  91 | t:  0 | loss: 0.000 | input:  02-07-16 | target:  16/Jul/2002 | inference:  16/Jul/2002<EOS>
# Epoch:  91 | t:  70 | loss: 0.000 | input:  05-01-09 | target:  09/Jan/2005 | inference:  09/Jan/2005<EOS>
# Epoch:  92 | t:  0 | loss: 0.000 | input:  94-12-30 | target:  30/Dec/1994 | inference:  30/Dec/1994<EOS>
# Epoch:  92 | t:  70 | loss: 0.000 | input:  06-02-04 | target:  04/Feb/2006 | inference:  04/Feb/2006<EOS>
# Epoch:  93 | t:  0 | loss: 0.000 | input:  08-10-25 | target:  25/Oct/2008 | inference:  25/Oct/2008<EOS>
# Epoch:  93 | t:  70 | loss: 0.000 | input:  00-05-22 | target:  22/May/2000 | inference:  22/May/2000<EOS>
# Epoch:  94 | t:  0 | loss: 0.000 | input:  83-04-12 | target:  12/Apr/1983 | inference:  12/Apr/1983<EOS>
# Epoch:  94 | t:  70 | loss: 0.000 | input:  29-01-21 | target:  21/Jan/2029 | inference:  21/Jan/2029<EOS>
# Epoch:  95 | t:  0 | loss: 0.000 | input:  91-03-22 | target:  22/Mar/1991 | inference:  22/Mar/1991<EOS>
# Epoch:  95 | t:  70 | loss: 0.000 | input:  06-08-12 | target:  12/Aug/2006 | inference:  12/Aug/2006<EOS>
# Epoch:  96 | t:  0 | loss: 0.000 | input:  96-03-30 | target:  30/Mar/1996 | inference:  30/Mar/1996<EOS>
# Epoch:  96 | t:  70 | loss: 0.000 | input:  26-07-24 | target:  24/Jul/2026 | inference:  24/Jul/2026<EOS>
# Epoch:  97 | t:  0 | loss: 0.000 | input:  91-02-25 | target:  25/Feb/1991 | inference:  25/Feb/1991<EOS>
# Epoch:  97 | t:  70 | loss: 0.000 | input:  99-03-17 | target:  17/Mar/1999 | inference:  17/Mar/1999<EOS>
# Epoch:  98 | t:  0 | loss: 0.027 | input:  29-11-08 | target:  08/Nov/2029 | inference:  08/Nov/2029<EOS>
# Epoch:  98 | t:  70 | loss: 0.001 | input:  97-05-21 | target:  21/May/1997 | inference:  21/May/1997<EOS>
# Epoch:  99 | t:  0 | loss: 0.001 | input:  97-12-30 | target:  30/Dec/1997 | inference:  30/Dec/1997<EOS>
# Epoch:  99 | t:  70 | loss: 0.001 | input:  15-11-04 | target:  04/Nov/2015 | inference:  04/Nov/2015<EOS>
