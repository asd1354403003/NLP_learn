# %%
from torch import nn,optim
import torch
from torch.nn.functional import cross_entropy,softmax
import utils
from torch.utils.data import DataLoader
import os

# %%
class ELMo(nn.Module):

    def __init__(self, v_dim, emb_dim, units, n_layers, lr):
        super().__init__()
        self.n_layers = n_layers
        self.units = units
        self.v_dim = v_dim

        # encoder
        self.word_embed = nn.Embedding(num_embeddings= v_dim, embedding_dim= emb_dim,padding_idx=0)
        self.word_embed.weight.data.normal_(0,0.1)

        # forward LSTM
        self.fs = nn.ModuleList(
            [nn.LSTM(input_size = emb_dim, hidden_size = units, batch_first=True) if i==0 else nn.LSTM(input_size = units, hidden_size = units, batch_first=True) for i in range(n_layers)])
        self.f_logits = nn.Linear(in_features=units, out_features=v_dim)

        # backward LSTM
        self.bs = nn.ModuleList(
            [nn.LSTM(input_size = emb_dim, hidden_size = units, batch_first=True) if i==0 else nn.LSTM(input_size = units, hidden_size = units, batch_first=True) for i in range(n_layers)])
        self.b_logits = nn.Linear(in_features=units, out_features=v_dim)

        self.opt = optim.Adam(self.parameters(),lr = lr)

    def forward(self,seqs):
        device = next(self.parameters()).device
        embedded = self.word_embed(seqs)    # [n, step, emb_dim]
        fxs = [embedded[:, :-1, :]]         # [n, step-1, emb_dim]
        bxs = [embedded[:, 1:, :]]          # [n, step-1, emb_dim]
        (h_f,c_f) = (torch.zeros(1,seqs.shape[0],self.units).to(device),torch.zeros(1,seqs.shape[0],self.units).to(device))
        (h_b,c_b) = (torch.zeros(1,seqs.shape[0],self.units).to(device),torch.zeros(1,seqs.shape[0],self.units).to(device))
        for fl,bl in zip(self.fs,self.bs):
            output_f,(h_f,c_f) = fl(fxs[-1], (h_f,c_f))   # [n, step-1, units], [1, n, units]
            fxs.append(output_f)
            
            output_b,(h_b,c_b) = bl(torch.flip(bxs[-1],dims=[1,]), (h_b,c_b)) # [n, step-1, units], [1, n, units]
            bxs.append(torch.flip(output_b,dims=(1,)))
        return fxs,bxs

    def step(self,seqs):
        self.opt.zero_grad()
        fo,bo = self(seqs)
        fo = self.f_logits(fo[-1])  # [n, step-1, v_dim]
        bo = self.b_logits(bo[-1])  # [n, step-1, v_dim]
        loss = (
            cross_entropy(fo.reshape(-1,self.v_dim),seqs[:,1:].reshape(-1)) +
            cross_entropy(bo.reshape(-1,self.v_dim),seqs[:,:-1].reshape(-1)))/2
        loss.backward()
        self.opt.step()
        return loss.cpu().detach().numpy(), (fo,bo)
    
    def get_emb(self,seqs):
        fxs,bxs = self(seqs)
        xs = [
            torch.cat((fxs[0][:,1:,:],bxs[0][:,:-1,:]),dim=2).cpu().data.numpy()
        ] + [
            torch.cat((f[:,1:,:],b[:,:-1,:]),dim=2).cpu().data.numpy() for f,b in zip(fxs[1:],bxs[1:])
        ]
        for x in xs:
            print("layers shape=",x.shape)
        return xs

# %%
def train():
    dataset = utils.MRPCSingle("./MRPC",rows=2000)
    UNITS = 256
    N_LAYERS = 2
    BATCH_SIZE = 16
    LEARNING_RATE = 2e-3
    print('num word: ',dataset.num_word)
    model = ELMo(v_dim = dataset.num_word,emb_dim = UNITS, units=UNITS, n_layers=N_LAYERS,lr=LEARNING_RATE)
    if torch.cuda.is_available():
        print("GPU train avaliable")
        device =torch.device("cuda")
        model = model.cuda()
    else:
        device = torch.device("cpu")
        model = model.cpu()
    loader = DataLoader(dataset,batch_size=BATCH_SIZE,shuffle=True)
    for i in range(10):
        for batch_idx , batch in enumerate(loader):
            batch = batch.type(torch.LongTensor).to(device)
            loss, (fo,bo) = model.step(batch)
            if batch_idx % 20 ==0:
                fp = fo[0].cpu().data.numpy().argmax(axis=1)
                bp = bo[0].cpu().data.numpy().argmax(axis=1)
                print("\n\nEpoch: ", i,
                "| batch: ", batch_idx,
                "| loss: %.3f" % loss,
                "\n| tgt: ", " ".join([dataset.i2v[i] for i in batch[0].cpu().data.numpy() if i != dataset.pad_id]),
                "\n| f_prd: ", " ".join([dataset.i2v[i] for i in fp if i != dataset.pad_id]),
                "\n| b_prd: ", " ".join([dataset.i2v[i] for i in bp if i != dataset.pad_id]),
                )
#     os.makedirs("./visual/models/elmo",exist_ok=True)
#     torch.save(model.state_dict(),"./visual/models/elmo/model.pth")
#     export_w2v(model,batch[:4],device)

# %%
def export_w2v(model,data,device):
    model.load_state_dict(torch.load("./visual/models/elmo/model.pth",map_location=device))
    emb = model.get_emb(data)
    print(emb)

# %%
if __name__ == "__main__":
    train()
# Out:
# downloading from https://mofanpy.com/static/files/MRPC/msr_paraphrase_train.txt
# completed
# downloading from https://mofanpy.com/static/files/MRPC/msr_paraphrase_test.txt
# completed
# num word:  12880
# GPU train avaliable
#
#
# Epoch:  0 | batch:  0 | loss: 9.464
# | tgt:  <GO> an artist painted a sign reading ``caution low flying planes ' ' on a building near ground zero , angering neighbors and stirring complaints . <SEP>
# | f_prd:  health health health health engineers engineers engineers engineers engineers engineers engineers engineers health health health health health health health health health health health health health health health health health health health health health health health health health
# | b_prd:  milestone isabel panic panic isabel isabel isabel isabel isabel isabel hard-wired panic panic panic flaws panic milestone milestone milestone milestone panic milestone milestone panic isabel hard-wired hard-wired hard-wired hard-wired hard-wired hard-wired hard-wired shipments shipments shipments jumped edgar
#
#
# Epoch:  0 | batch:  20 | loss: 4.366
# | tgt:  <GO> the free service was originally intended to block about <NUM> percent of telemarketer calls . <SEP>
# | f_prd:  the
# | b_prd:
#
#
# Epoch:  0 | batch:  40 | loss: 4.644
# | tgt:  <GO> they argue that proposed congressional redistricting maps reviewed by the legislature would disenfranchise minorities and rural texas . <SEP>
# | f_prd:  the the the the the the , , , , , ,
# | b_prd:
#
#
# Epoch:  0 | batch:  60 | loss: 4.393
# | tgt:  <GO> the man , who entered the post office in lakeside shortly before <NUM> p.m. , gave up to deputies about <NUM> : <NUM> p.m. <SEP>
# | f_prd:  the the the the , , , , , , , , , , , , ,
# | b_prd:  <GO> , , , , <GO> , <GO> , , , , , , , , , , , , ,
#
#
# Epoch:  0 | batch:  80 | loss: 4.373
# | tgt:  <GO> trans fat accounts for <NUM> percent of americans ' daily calories , compared to <NUM> percent to <NUM> percent for saturated fat . <SEP>
# | f_prd:  the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the . . .
#
#
# Epoch:  0 | batch:  100 | loss: 4.133
# | tgt:  <GO> sorkin , who faces charges of conspiracy to obstruct justice and lying to a grand jury , was to have been tried separately . <SEP>
# | f_prd:  the the the , , , , , , , , , , , . . . . . . . . .
# | b_prd:  <GO> <GO> <GO> <GO> the the the the the the the , , , , , , , , , , , , . .
#
#
# Epoch:  0 | batch:  120 | loss: 3.990
# | tgt:  <GO> the fbi is trying to determine when white house officials and members of the vice president 's staff focused on wilson and learned about his wife 's employment . <SEP>
# | f_prd:  the the the the , , , , , , , , , , , , , , , , , , the . . . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , , , , , , , , , , , , the . . <SEP>
#
#
# Epoch:  0 | batch:  140 | loss: 4.017
# | tgt:  <GO> right now , only six states do : arkansas , michigan , minnesota , new jersey , virginia , and wisconsin . <SEP>
# | f_prd:  the the the the the , , , , , the , , , the the the the . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> the the the the the the the the the the the the the the the the the the . . <SEP>
#
#
# Epoch:  0 | batch:  160 | loss: 3.944
# | tgt:  <GO> computer associates , emc , ibm , sun microsystems , and veritas are also onboard to support the storage standard . <SEP>
# | f_prd:  the the , , , , , , , , , , , , , , the . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> , , , , , the the the , the , the the , , the the <NUM> . <SEP>
#
#
# Epoch:  0 | batch:  180 | loss: 3.838
# | tgt:  <GO> <quote> i think it happened very quickly , <quote> houston police department homicide investigator phil yochum said of the crime . <SEP>
# | f_prd:  the the the , , , the , , , , , , , , the , . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> the , , the , the the the the the the the the the the the the said . <SEP>
#
#
# Epoch:  0 | batch:  200 | loss: 3.680
# | tgt:  <GO> peterson told police he fished alone in san francisco bay on christmas eve , returning to an empty house . <SEP>
# | f_prd:  the the , , , , , , the , , , , , the the the . . . <SEP>
# | b_prd:  <GO> <GO> the , , , , , , , , , , , , , , , the said . <SEP>
#
#
# Epoch:  0 | batch:  220 | loss: 3.933
# | tgt:  <GO> in early u.s. trade , the euro was down <NUM> percent at $ <NUM> < eur = > . <SEP>
# | f_prd:  the the the the the the the the the , , , , <NUM> <NUM> the . . . <SEP>
# | b_prd:  <GO> <GO> the the , , the , , , <NUM> , , , , , <NUM> <NUM> said . <SEP>
#
#
# Epoch:  0 | batch:  240 | loss: 4.077
# | tgt:  <GO> <quote> the whole thing is a travesty , <quote> fumed brent newbury , president of the rockland county patrolmen 's benevolent association . <SEP>
# | f_prd:  the the the the the the the , the the the the the the the the the , the the the . . <SEP>
# | b_prd:  <GO> <GO> <GO> the , the the , the , , the , the , the the , the , the the said . <SEP>
#
#
# Epoch:  1 | batch:  0 | loss: 4.017
# | tgt:  <GO> virtual pc , which microsoft acquired from connectix corp. in february , will not run on the g5 , the company said . <SEP>
# | f_prd:  the the , the the the the the , the the , the the the , the the , the the . . <SEP>
# | b_prd:  <GO> <GO> the the the the , , , , the , , , the , the the <NUM> the the <NUM> said . <SEP>
#
#
# Epoch:  1 | batch:  20 | loss: 3.700
# | tgt:  <GO> this was double the $ <NUM> million reported for the first three months of <NUM> . <SEP>
# | f_prd:  the the the the the <NUM> <NUM> <NUM> <NUM> the the the , . . . <SEP>
# | b_prd:  <GO> <GO> , , , , <NUM> , , , , , , said <NUM> said . <SEP>
#
#
# Epoch:  1 | batch:  40 | loss: 3.621
# | tgt:  <GO> the deficit is still expected to top $ <NUM> billion in <NUM> -- even with an improving economy . <SEP>
# | f_prd:  the the , the the , the , <NUM> <NUM> , the , , , the the . . <SEP>
# | b_prd:  <GO> <GO> , , the , the , , <NUM> , the , the , , , the said . <SEP>
#
#
# Epoch:  1 | batch:  60 | loss: 3.690
# | tgt:  <GO> fbi spokesman steve lazarus did not immediately return a phone call for comment on friday . <SEP>
# | f_prd:  the , , the the the the the , the , , the . . . <SEP>
# | b_prd:  <GO> <GO> , , , , , the , , , , the , the said . <SEP>
#
#
# Epoch:  1 | batch:  80 | loss: 3.457
# | tgt:  <GO> the <NUM>-year bond < us30yt = rr > was down <NUM> / <NUM> for a yield of <NUM> percent , up from <NUM> percent late thursday . <SEP>
# | f_prd:  the the was was 's 's 's <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> the <NUM> the , <NUM> the <NUM> <NUM> , . . . <SEP>
# | b_prd:  <GO> <GO> , the , , , , , , the , the <NUM> , the , or <NUM> percent , , or <NUM> the the <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  100 | loss: 3.525
# | tgt:  <GO> <quote> this is an extremely heartrending time for the entire brandeis university community . <SEP>
# | f_prd:  the the the the the the , , the the of . . . <SEP>
# | b_prd:  <GO> <GO> , , , , the , , , the the the <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  120 | loss: 3.997
# | tgt:  <GO> its safe to assume the senate is prepared to pass some form of a cap .... the level of it is to be debated . <SEP>
# | f_prd:  the the , the , the , the , the , the , the the , , the , the , the the . . <SEP>
# | b_prd:  <GO> the , the , the , the , the , the , , , , , the , , , , the the said . <SEP>
#
#
# Epoch:  1 | batch:  140 | loss: 3.466
# | tgt:  <GO> the news has caused a rush of people to the knox county health department to get vaccinated . <SEP>
# | f_prd:  the dow , the , the , the , the the , the , , the . . <SEP>
# | b_prd:  <GO> <GO> , , , the , the , , the , , , , to the <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  160 | loss: 3.171
# | tgt:  <GO> the report shows that drugs sold in canadian pharmacies are manufactured in facilities approved by health canada - the fda 's counterpart in canada . <SEP>
# | f_prd:  the technology-laced , , the , , the , , the , the , , the , , the the , the . the . <SEP>
# | b_prd:  <GO> the , , , , , the , , , , , , , , the , , the percent , , the <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  180 | loss: 3.503
# | tgt:  <GO> the official , who spoke on condition of anonymity , said that two iraqis and two saudis detained after the attack gave information leading to the arrest of the others . <SEP>
# | f_prd:  the dow has the the , the , the , the the the the , the , , , the new , the , , the the of the . . <SEP>
# | b_prd:  <GO> the <NUM> , , , the , the , , , the the , to the , , , the , , the , to the , to the <NUM> . <SEP>
# Epoch:  1 | batch:  200 | loss: 3.703
# | tgt:  <GO> vivendi shares closed <NUM> percent at <NUM> euros in paris after falling <NUM> percent on monday . <SEP>
# | f_prd:  the said , , , , <NUM> percent , the the the , , , . . <SEP>
# | b_prd:  <GO> <GO> , or <NUM> , the , , , , to $ <NUM> percent the <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  220 | loss: 3.236
# | tgt:  <GO> the broader market also retreated , having climbed higher for four consecutive weeks . <SEP>
# | f_prd:  the technology-laced nasdaq composite <NUM> was the the , , the , . . <SEP>
# | b_prd:  <GO> the , , the , , , , , to , the said . <SEP>
#
#
# Epoch:  1 | batch:  240 | loss: 3.690
# | tgt:  <GO> moffitt said the results need to be replicated in another study before testing of individuals for presence of the long or short versions of the gene will be pursued . <SEP>
# | f_prd:  the , the first , , the , , the , , the , the , the , the first , , , , the first , the . . <SEP>
# | b_prd:  <GO> <GO> , , , , the , , to the , , <NUM> , , the <NUM> , , , , , <NUM> , the , to the said . <SEP>
#
#
# Epoch:  2 | batch:  0 | loss: 3.394
# | tgt:  <GO> the man , who entered the post office in lakeside shortly before <NUM> p.m. , gave up to deputies about <NUM> : <NUM> p.m. <SEP>
# | f_prd:  the dow , the , the company , , the , , the , , <NUM> <NUM> <NUM> the , the percent <NUM> . .
# | b_prd:  <GO> the <NUM> , , , the , <NUM> the , <NUM> $ <NUM> <NUM> , , <NUM> the , the <NUM> . . . <SEP>
#
#
# Epoch:  2 | batch:  20 | loss: 3.243
# | tgt:  <GO> axcan 's shares closed down <NUM> canadian cents , or <NUM> percent , at c $ <NUM> in toronto on tuesday . <SEP>
# | f_prd:  the , the , <NUM> <NUM> , , , <NUM> <NUM> , , <NUM> <NUM> <NUM> <NUM> percent <NUM> <NUM> <NUM> . <SEP>
# | b_prd:  <GO> <GO> the , , $ <NUM> <NUM> <NUM> , or <NUM> percent , , to the <NUM> the <NUM> <NUM> <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  40 | loss: 3.265
# | tgt:  <GO> mr. manuel and his group entered the united states by walking across the bridge linking matamoros and brownsville . <SEP>
# | f_prd:  the dow , the first , the first , , the , the first of the , the . <SEP>
# | b_prd:  <GO> <GO> <NUM> , the , of the , , the , of the , , <NUM> the said . <SEP>
#
#
# Epoch:  2 | batch:  60 | loss: 3.480
# | tgt:  <GO> the mpx200 , which will sell for $ <NUM> , is now available through at & t wireless ' mmode service . <SEP>
# | f_prd:  the dow , the the the , the <NUM> , <NUM> the , , the the the , and . . . <SEP>
# | b_prd:  <GO> the <NUM> , , the , to $ <NUM> , , , <NUM> <NUM> , the , , , <NUM> <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  80 | loss: 3.786
# | tgt:  <GO> minister saud al-faisal visit was disclosed monday by two administration officials who discussed it on condition of not being identified by name . <SEP>
# | f_prd:  the said standard , , the , , the , , , , , , the , the the the . the . <SEP>
# | b_prd:  <GO> <GO> , the , , , , the , , , , , , , percent , , , percent the said . <SEP>
#
#
# Epoch:  2 | batch:  100 | loss: 3.507
# | tgt:  <GO> a second bomb , evidently carried by the other woman , did not explode ; the authorities detonated the explosives later . <SEP>
# | f_prd:  the dow standard , the was , the first states , the the the , the first , , government . . <SEP>
# | b_prd:  <GO> the the <NUM> , , , in the the percent , , the , , , , in the percent said . <SEP>
#
#
# Epoch:  2 | batch:  120 | loss: 3.486
# | tgt:  <GO> <quote> the republicans went into a closet , met with themselves , and announced a compromise , <quote> hollings said in a statement . <SEP>
# | f_prd:  the the first , to the first of the the the , the the the company of <quote> the and the the . . <SEP>
# | b_prd:  <GO> <GO> the , , , the <NUM> , , , percent , , of the percent , the , , of the said . <SEP>
#
#
# Epoch:  2 | batch:  140 | loss: 3.365
# | tgt:  <GO> the latest toll given by officials to state media was <NUM> dead and over <NUM> injured . <SEP>
# | f_prd:  the dow jones , the the the the , , the , , the the percent . <SEP>
# | b_prd:  <GO> the , , <NUM> , <NUM> the , , $ <NUM> percent <NUM> in the <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  160 | loss: 3.211
# | tgt:  <GO> china , haunted by the spread of sars in its vast countryside , has threatened to execute or jail for life anyone who intentionally spreads the killer virus . <SEP>
# | f_prd:  the , the , the united , the , the company york , <quote> the , the the the , the , , , , , world . . <SEP>
# | b_prd:  <GO> <NUM> the <NUM> , the <NUM> the , of the , percent , , , the , , , to to , to , in the the said . <SEP>
#
#
# Epoch:  2 | batch:  180 | loss: 3.400
# | tgt:  <GO> the equivalent of <NUM> <NUM>-gallon barrels of transuranic and low-level radioactive waste , some of it mixed with hazardous chemicals , is buried at hanford . <SEP>
# | f_prd:  the company of the , , , the the the be , , <quote> , the , , the the in <quote> the in the . <SEP>
# | b_prd:  <GO> the <NUM> or <NUM> <NUM> <NUM> , , , , , <NUM> , <NUM> , , , , , <NUM> , the , in <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  200 | loss: 3.698
# | tgt:  <GO> blagojevich reiterated his stance wednesday to not prop up the budget with a gambling expansion . <SEP>
# | f_prd:  the , the first the to the the , to new of the new . . <SEP>
# | b_prd:  <GO> <quote> of , , , to the , of the , of and the said . <SEP>
#
#
# Epoch:  2 | batch:  220 | loss: 3.870
# | tgt:  <GO> the securities and exchange commission filed a civil fraud suit against the teen in boston . <SEP>
# | f_prd:  the technology-laced was the was was the new york of , the new of the . <SEP>
# | b_prd:  <GO> the <NUM> the the , of the and the , in the percent the said . <SEP>
#
#
# Epoch:  2 | batch:  240 | loss: 3.490
# | tgt:  <GO> a nationally board certified teacher with a master 's degree , kelley makes a salary of $ <NUM> in his 30th year . <SEP>
# | f_prd:  the technology-laced states has us30yt , the first , new , <quote> , the york , the <NUM> billion the year york . <SEP>
# | b_prd:  <GO> the the , the , , the <NUM> the <NUM> , , , the <NUM> to $ <NUM> in the the said . <SEP>
#
#
# Epoch:  3 | batch:  0 | loss: 3.124
# | tgt:  <GO> axelrod died in his sleep of heart failure , said his daughter , nina axelrod . <SEP>
# | f_prd:  the said , the first , the , to <quote> the company 's <quote> said . <SEP>
# | b_prd:  <GO> he , of the <NUM> the the <NUM> , of the <NUM> , the said . <SEP>
#
#
# Epoch:  3 | batch:  20 | loss: 3.039
# | tgt:  <GO> u.s. forces recently apprehended some <NUM> suspected foreign militants near the syrian border and are now interrogating them . <SEP>
# | f_prd:  the company is that the , , the , in the new york of the the the the . <SEP>
# | b_prd:  <GO> <GO> he <NUM> to to the the was <NUM> in the the <NUM> , , <NUM> in <NUM> . <SEP>
#
#
# Epoch:  3 | batch:  40 | loss: 3.282
# | tgt:  <GO> the family stopped for lunch at freshwater spit , where several children went to the water 's edge to play in the surf shortly after noon . <SEP>
# | f_prd:  the first of the the , the , , <quote> the , , , the first of first to the the the first 's of the . <SEP>
# | b_prd:  <GO> the the <NUM> , , the the <NUM> , , the , , , , , the , the , of the , , the said . <SEP>
#
#
# Epoch:  3 | batch:  60 | loss: 3.517
# | tgt:  <GO> sumitomo mitsui financial ( jp : <NUM> : news , chart , profile ) was down <NUM> percent at <NUM> yen . <SEP>
# | f_prd:  the said , have be , <NUM> percent <NUM> , <NUM> , <NUM> , , <NUM> <NUM> percent , <NUM> . . <SEP>
# | b_prd:  <GO> <GO> the <NUM> the <NUM> $ <NUM> , <NUM> , <NUM> , <NUM> , , $ <NUM> , at <NUM> <NUM> . <SEP>
#
#
# Epoch:  3 | batch:  80 | loss: 3.031
# | tgt:  <GO> they said he would be open to letting that license go to the city of chicago . <SEP>
# | f_prd:  the was the said be the to the the the , , the first of the . <SEP>
# | b_prd:  <GO> <GO> <quote> he the be , the , a to , in the percent in said . <SEP>
#
#
# Epoch:  3 | batch:  100 | loss: 3.385
# | tgt:  <GO> the food and drug administration ultimately denied imclone 's drug application in december <NUM> , saying that an erbitux clinical trial was deficient . <SEP>
# | f_prd:  the dow , the 's , been that , <NUM> , , the , , according the the company 's and , . . <SEP>
# | b_prd:  <GO> the , the <NUM> , , , <NUM> the <NUM> <NUM> to $ <NUM> , , , to to the <NUM> in <NUM> . <SEP>
# Epoch:  3 | batch:  120 | loss: 2.672
# | tgt:  <GO> the stock of juniper networks inc. rose sharply monday after the mountain view , calif.-based network-equipment maker announced a distribution and development deal with lucent technologies inc . <SEP>
# | f_prd:  the new was the management was , to to , the new of , <NUM> than and , in year of the 's in the control . . <SEP>
# | b_prd:  <GO> the <NUM> in the dow <NUM> , , , of the the <NUM> , , , , , the , the a , of the percent said . <SEP>
#
#
# Epoch:  3 | batch:  140 | loss: 3.566
# | tgt:  <GO> the report shows that drugs sold in canadian pharmacies are manufactured in facilities approved by health canada - the fda 's counterpart in canada . <SEP>
# | f_prd:  the technology-laced , that the that the the , , not to the , to the , , the united of week to the . <SEP>
# | b_prd:  <GO> the was <NUM> and was said the the it be said and and <NUM> to , percent in the <NUM> and said in said . <SEP>
#
#
# Epoch:  3 | batch:  160 | loss: 3.267
# | tgt:  <GO> he later learned that the incident was caused by the concorde 's sonic boom . <SEP>
# | f_prd:  the was , to the united , the the the united 's week . . <SEP>
# | b_prd:  <GO> he was said in the he was said in in <NUM> the the said . <SEP>
#
#
# Epoch:  3 | batch:  180 | loss: 3.054
# | tgt:  <GO> the victims drank tainted coffee after the april <NUM> worship service at gustaf adolph lutheran church in new sweden . <SEP>
# | f_prd:  the company said attorney was , the <NUM> <NUM> percent , , the york york and and the york . <SEP>
# | b_prd:  <GO> the said was was <NUM> in to $ <NUM> the <NUM> in <NUM> <NUM> the percent in in <NUM> . <SEP>
#
#
# Epoch:  3 | batch:  200 | loss: 3.356
# | tgt:  <GO> while robbery appeared to be the motive , the suspects fled before they could take anything , he said . <SEP>
# | f_prd:  the the , to be the first , <quote> company , <quote> the and be the to <quote> said . <SEP>
# | b_prd:  <GO> <GO> was , to of the said , the , , , , to , <NUM> , he said . <SEP>
#
#
# Epoch:  3 | batch:  220 | loss: 2.857
# | tgt:  <GO> roslyn shares gained <NUM> cents to close at $ <NUM> yesterday in nasdaq trading . <SEP>
# | f_prd:  the shares fell <NUM> cents , $ <NUM> <NUM> <NUM> , on <NUM> . . <SEP>
# | b_prd:  <GO> <GO> shares $ <NUM> <NUM> to , to $ on <NUM> the <NUM> <NUM> . <SEP>
#
#
# Epoch:  3 | batch:  240 | loss: 3.615
# | tgt:  <GO> community college students will see their tuition rise by $ <NUM> to $ <NUM> or <NUM> percent . <SEP>
# | f_prd:  the has has has be the <NUM> in to the <NUM> million <NUM> <NUM> million <NUM> percent . <SEP>
# | b_prd:  <GO> <GO> the <NUM> to to to to <NUM> to $ , to $ , $ <NUM> <NUM> . <SEP>
#
#
# Epoch:  4 | batch:  0 | loss: 3.162
# | tgt:  <GO> half the women received a daily tablet of the combination oestrogen plus progestin while the rest were given a placebo . <SEP>
# | f_prd:  the of year was the first executive , the first , the the , the first of the the statement . <SEP>
# | b_prd:  <GO> in the , of the the <NUM> of the it is to , of the it and in the said . <SEP>
#
#
# Epoch:  4 | batch:  20 | loss: 3.168
# | tgt:  <GO> the hearing occurred a day after the pentagon for the first time singled out an officer , dallager , for not addressing the scandal . <SEP>
# | f_prd:  the united said the <NUM>-year-old that the united , the first time , in , conclusions , <quote> , <quote> the be the statement . <SEP>
# | b_prd:  <GO> the said , the said of the said , the the , , , united <NUM> , percent , , to of the said . <SEP>
#
#
# Epoch:  4 | batch:  40 | loss: 2.989
# | tgt:  <GO> like the power4 , the power5 contains two processor cores on one chip . <SEP>
# | f_prd:  the the first , the dow 's the years , in the . . <SEP>
# | b_prd:  <GO> in the <NUM> of the and of the percent , of the said . <SEP>
#
#
# Epoch:  4 | batch:  60 | loss: 2.992
# | tgt:  <GO> tropical storm warnings were in place thursday for jamaica and haiti and watches for the western dominican republic , the southeastern bahamas and the turks and caicos islands . <SEP>
# | f_prd:  the year has , a the , , the , the and the , the world , , , <quote> company officer <quote> the united and the . . <SEP>
# | b_prd:  <GO> the industrial , said to on , of , , , , , , the the united <NUM> , the , , , the , and and said . <SEP>
#
#
# Epoch:  4 | batch:  80 | loss: 3.241
# | tgt:  <GO> avants , wearing a light brown jumpsuit , had tubes in his nose and a portable oxygen tank beside him . <SEP>
# | f_prd:  the , the the first , , , <quote> not , the new and the world site site . . . <SEP>
# | b_prd:  <GO> shares , , 's 's security <NUM> , , , in the , , a and 's and and said . <SEP>
#
#
# Epoch:  4 | batch:  100 | loss: 2.988
# | tgt:  <GO> the stretch of danube river passing through the balkans dropped so low that wrecks of world war ii boats became visible . <SEP>
# | f_prd:  the company of the first , , the united , to as , the , the and , in in the . <SEP>
# | b_prd:  <GO> a shares the 's composite said of the it that be said and news a the year of he on said . <SEP>
#
#
# Epoch:  4 | batch:  120 | loss: 2.868
# | tgt:  <GO> of those three , only dillard 's responded to the survey that ranked <NUM> large companies on employment , marketing , procurement , community reinvestment and charitable donations . <SEP>
# | f_prd:  <quote> the , , the the 's first of the first , the the , cent , the , and and the , the and and year . . <SEP>
# | b_prd:  <GO> in in <NUM> , , <NUM> was , in <NUM> <NUM> , to in to , , <NUM> on <NUM> , <NUM> of , , a to said . <SEP>
#
#
# Epoch:  4 | batch:  140 | loss: 2.923
# | tgt:  <GO> several passing vehicles and an adjacent shop were also damaged in the explosion . <SEP>
# | f_prd:  the has that , the first investigation , been been in the <NUM> . <SEP>
# | b_prd:  <GO> standard the it that the been it have be said in the said . <SEP>
#
#
# Epoch:  4 | batch:  160 | loss: 2.969
# | tgt:  <GO> wall street is debating whether the central bank will say risks are tilted toward weakness or balanced with inflation . <SEP>
# | f_prd:  the has has the the the company court , be the and not , the , <quote> , the . <SEP>
# | b_prd:  <GO> the it is said of the the it an the it to and to , be , in said . <SEP>
#
#
# Epoch:  4 | batch:  180 | loss: 3.311
# | tgt:  <GO> the g + j executive was testifying in manhattan 's state supreme court where o 'donnell and g + j are suing each other for breach of contract . <SEP>
# | f_prd:  <quote> new 's us30yt commission , been to the 's first , court , the and , other 's is , been in of , the of the . <SEP>
# | b_prd:  <GO> the nasdaq standard the it be said in it the the the , and william , and nasdaq and it and of and iraq the news in said . <SEP>
#
#
# Epoch:  4 | batch:  200 | loss: 2.725
# | tgt:  <GO> parrado remained on a coast guard cutter wednesday as immigration officials attempt to determine his status , the coast guard said . <SEP>
# | f_prd:  the 's that the first , , that and the and , to be the first , <quote> company said . . <SEP>
# | b_prd:  <GO> he , of a the said said , of and a , to of the percent of the the he said . <SEP>
#
#
# Epoch:  4 | batch:  220 | loss: 3.080
# | tgt:  <GO> yucaipa bought dominick 's in <NUM> for $ <NUM> million and sold it to safeway for $ <NUM> billion in <NUM> . <SEP>
# | f_prd:  the shares also of <NUM> <NUM> percent <NUM> <NUM> , , <NUM> <NUM> , <NUM> , the <NUM> in in <NUM> . <SEP>
# | b_prd:  <GO> <quote> dow percent <NUM> $ percent to $ <NUM> <NUM> has on <NUM> in percent to $ <NUM> <NUM> $ <NUM> . <SEP>
#
#
# Epoch:  4 | batch:  240 | loss: 3.191
# | tgt:  <GO> it was the third time in four years that wildfires forced the park to close . <SEP>
# | f_prd:  the said also first quarter in the years , the were a <NUM> 's <NUM> . <SEP>
# | b_prd:  <GO> shares in the a said about a said and have in a , to said . <SEP>
#
#
# Epoch:  5 | batch:  0 | loss: 2.606
# | tgt:  <GO> he said some issues - including division alignments - will be resolved if the conference expands . <SEP>
# | f_prd:  the said the is of was the , , was be a in the company . . <SEP>
# | b_prd:  <GO> he said the said , 's us10yt = it to be , of the he said . <SEP>
#
#
# Epoch:  5 | batch:  20 | loss: 2.756
# | tgt:  <GO> jane doe , deciding to fight the subpoena , asked verizon to withhold her name . <SEP>
# | f_prd:  the damascus , the the be the state , <quote> to to be the statement . <SEP>
# | b_prd:  <GO> robert however , , will of the <NUM> and , , to to the said . <SEP>
# Epoch:  5 | batch:  40 | loss: 2.429
# | tgt:  <GO> the name for the robot , due to be launched at <NUM> : <NUM> p.m. ( <NUM> : <NUM> p.m. ) on sunday , was selected from among <NUM> names submitted by u.s. <SEP>
# | f_prd:  the new , the first , which to <NUM> up in <NUM> years <NUM> percent , <NUM> ) <NUM> percent , and the and and <NUM> to the the percent in in <NUM> .
# | b_prd:  <GO> the shares in the <NUM> , , to was , $ <NUM> or <NUM> <NUM> $ <NUM> or <NUM> <NUM> <NUM> on <NUM> , , <NUM> , 's and he said . . <SEP>
#
#
# Epoch:  5 | batch:  60 | loss: 2.535
# | tgt:  <GO> this morning , at um 's new york office , coen revised his expectations downward , saying that spending would instead rise <NUM> percent to $ <NUM> billion . <SEP>
# | f_prd:  the year , the <NUM> 's year york stock in including and to share , , including and have was be of <NUM> million , <NUM> <NUM> billion . <SEP>
# | b_prd:  <GO> <GO> <NUM> , in poor the new the <NUM> the a , 's <NUM> <NUM> , , , , and to to <NUM> , to $ <NUM> said . <SEP>
#
#
# Epoch:  5 | batch:  80 | loss: 2.586
# | tgt:  <GO> the other <NUM> people in the building , including harrison 's ex-girlfriend , were not injured , police spokesman don aaron said . <SEP>
# | f_prd:  the new has people , the company , which the 's ex-girlfriend , and not been and and said and 't said . <SEP>
# | b_prd:  <GO> the about <NUM> <NUM> of the <NUM> , , poor the <NUM> , , the <NUM> , <NUM> , , he <NUM> . <SEP>
#
#
# Epoch:  5 | batch:  100 | loss: 2.766
# | tgt:  <GO> the women had follow-up examinations in <NUM>- , <NUM>- and <NUM>- , but were not asked about stress again . <SEP>
# | f_prd:  the company has also sent to the , and , the , and he not not to <NUM> . . <SEP>
# | b_prd:  <GO> the he was was <NUM> , <NUM> , , , <NUM> , , , have to for on said . <SEP>
#
#
# Epoch:  5 | batch:  120 | loss: 2.747
# | tgt:  <GO> winslet , <NUM> , has a three-year-old daughter mia by her first husband , british film producer jim threapleton . <SEP>
# | f_prd:  the , <NUM> , the have profit profit , , the <NUM> <NUM> , according county 's in partnership . <SEP>
# | b_prd:  <GO> <NUM> , <NUM> , , the 's <NUM> <NUM> of the the <NUM> , to , , <NUM> <NUM> . <SEP>
#
#
# Epoch:  5 | batch:  140 | loss: 3.040
# | tgt:  <GO> sarah weddington , the abortion advocate and lawyer who originally represented mccorvey , did not immediately return a call seeking comment . <SEP>
# | f_prd:  the year , the company shocked of chief , had , as , and not not not to conclusions 's . . <SEP>
# | b_prd:  <GO> <GO> <NUM> , the the , 's , , have for <NUM> , did did to to to have to said . <SEP>
#
#
# Epoch:  5 | batch:  160 | loss: 2.879
# | tgt:  <GO> there was no way the man could hear him , but he turned in the rescuers ' direction , forlorn , hopeless . <SEP>
# | f_prd:  the said the immediate the first of be a , <quote> he was to the united , has of <quote> , <quote> . <SEP>
# | b_prd:  <GO> he <quote> a of the , to on said , said was , of the , al <NUM> , <NUM> , said . <SEP>
#
#
# Epoch:  5 | batch:  180 | loss: 2.095
# | tgt:  <GO> the us responded coolly to the eu deadline , warning that trade sanctions would backfire by hurting european consumers . <SEP>
# | f_prd:  the company department is to the united states , said the the as have be to the iraq . . <SEP>
# | b_prd:  <GO> the i be , of the the said , , chief & he and said to to of said . <SEP>
#
#
# Epoch:  5 | batch:  200 | loss: 2.641
# | tgt:  <GO> the swiss franc rose nearly a third of a centime against the dollar and was last at <NUM> < chf = > to the greenback . <SEP>
# | f_prd:  the company jones supply to <NUM> <NUM> york <NUM> <NUM> on <NUM> <NUM> in the <NUM> week <NUM> percent share = index of <NUM> = . <SEP>
# | b_prd:  <GO> the composite also was was the <NUM> on a <NUM> of the <NUM> <NUM> <NUM> <NUM> $ <NUM> < us30yt percent according in the said . <SEP>
#
#
# Epoch:  5 | batch:  220 | loss: 2.402
# | tgt:  <GO> sony ericsson also said it would shut down its gsm / umts r & d center in munich , germany , to increase profitability . <SEP>
# | f_prd:  <quote> 's <NUM> , the would be up to 1,700-square-mile , <NUM> million of combat ) in the , a and and be . . <SEP>
# | b_prd:  <GO> dow , , , , not is to a department with 's los and the , in <NUM> and percent , to on said . <SEP>
#
#
# Epoch:  5 | batch:  240 | loss: 3.040
# | tgt:  <GO> the two had battled over custody and he allegedly told her in an angry phone call that he had no intention of following their new custody agreement . <SEP>
# | f_prd:  the company states been the the of the was not the wife the wife revolutions , , the was a sign of the the sensationalism york . . <SEP>
# | b_prd:  <GO> <GO> he has is 's said said and who on said of a an to said said he and the percent and for the 's the said . <SEP>
#
#
# Epoch:  6 | batch:  0 | loss: 2.299
# | tgt:  <GO> <quote> we have found the smoking gun , <quote> investigating board member scott hubbard said . <SEP>
# | f_prd:  <quote> we are not the nation , , <quote> said the 's and . said . <SEP>
# | b_prd:  <GO> <quote> we has in the a said , , 's 's said , he said . <SEP>
#
#
# Epoch:  6 | batch:  20 | loss: 2.310
# | tgt:  <GO> eu ministers were invited to the conference but canceled because the union is closing talks on agricultural reform , said gerry kiely , a eu agriculture representative in washington . <SEP>
# | f_prd:  the minister , not to be united in the in the government 's not to in the city , <quote> he comstock , <quote> personal court court in . . <SEP>
# | b_prd:  <GO> the it was , in a , that said , the , , to , of on <NUM> , , jr <NUM> , the the the said of said . <SEP>
#
#
# Epoch:  6 | batch:  40 | loss: 2.244
# | tgt:  <GO> the case is illinois v. telemarketing associates , <NUM>- . <SEP>
# | f_prd:  the company , clearly similar <NUM> and , <NUM> . <SEP>
# | b_prd:  <GO> the it to for , the sept to said . <SEP>
#
#
# Epoch:  6 | batch:  60 | loss: 2.727
# | tgt:  <GO> <quote> a really robust space program could be had for a mere <NUM> cents a day from each person , <quote> he said . <SEP>
# | f_prd:  <quote> the actions catcher standards , , be in in the coma , , , share , the , , <quote> said said . <SEP>
# | b_prd:  <GO> <GO> the a the the , will index <NUM> at a or <NUM> cents a <NUM> for the <NUM> , , he said . <SEP>
#
#
# Epoch:  6 | batch:  80 | loss: 2.884
# | tgt:  <GO> officials at brandeis said this was an <quote> extremely heartrending <quote> time for the campus . <SEP>
# | f_prd:  he said the 's the week not <quote> <quote> pension <quote> <quote> to the war . <SEP>
# | b_prd:  <GO> <GO> of he said it is a the an a a war of the said . <SEP>
#
#
# Epoch:  6 | batch:  100 | loss: 2.628
# | tgt:  <GO> mr. holden toured northmoor , where between <NUM> and <NUM> homes were either damaged or destroyed and the town hall and police station also were damaged . <SEP>
# | f_prd:  <quote> kenny have northmoor , <NUM> the <NUM> : <NUM> percent were killed <NUM> in <NUM> the <NUM> company of of the said said killed expected . <SEP>
# | b_prd:  <GO> the maker al <NUM> , <NUM> $ <NUM> and <NUM> , had be , be , of the and <NUM> and 's , and be <NUM> . <SEP>
#
#
# Epoch:  6 | batch:  120 | loss: 2.389
# | tgt:  <GO> but gordon emphasized that the legislation he introduced last week is <quote> a lesson-learned bill and not a reflection on admiral ( harold ) gehman 's handling of the columbia investigation . <quote> <SEP>
# | f_prd:  <quote> he resembled in the company is was in the and a a disgrace 's and the be link on the , <quote> weapons and 's commissioner of the world 's . <SEP> <SEP>
# | b_prd:  <GO> <GO> dow said said the said been <quote> this it , , a the it is as a said on . on business and nation the part in the the said . <quote> <SEP>
#
#
# Epoch:  6 | batch:  140 | loss: 2.421
# | tgt:  <GO> but in the end , all the worm did was visit a pornography site , said vincent weafer , a security director with symantec security response in california . <SEP>
# | f_prd:  <quote> the the first of the the company 's not not to predominant , , <quote> the allen , said narcotic executive of <NUM> company association , the . <SEP>
# | b_prd:  <GO> <GO> of the <NUM> of , the , it to for a web <NUM> , , robert <NUM> , and and , of for of <quote> of said . <SEP>
#
#
# Epoch:  6 | batch:  160 | loss: 2.317
# | tgt:  <GO> other gainers included lexmark , which rose $ us3.95 to $ us63.35 , recouping some of the $ us14.10 it lost monday . <SEP>
# | f_prd:  the shares ago in , who said <NUM> <NUM> a $ <NUM> a or $ of $ $ <NUM> a on a . <SEP>
# | b_prd:  <GO> 's was on <NUM> , , to $ , to , <NUM> , , percent on a to said he on said . <SEP>
# Epoch:  6 | batch:  180 | loss: 2.793
# | tgt:  <GO> the u.n. nuclear watchdog reprimanded iran on thursday for failing to comply with its nuclear safeguards obligations and called on tehran to unconditionally accept stricter inspections by the agency . <SEP>
# | f_prd:  the united atomic circuit welcomes on of the and the to be with the baby subsidiary , and he it the , the , the than to the facts . <SEP>
# | b_prd:  <GO> the chief prime who be said on wednesday to expected to according of and nuclear web it be him of according and who on be comment on the said . <SEP>
#
#
# Epoch:  6 | batch:  200 | loss: 2.528
# | tgt:  <GO> saddam loyalists have been blamed for sabotaging the nation 's infrastructure , as well as frequent attacks on u.s. soldiers . <SEP>
# | f_prd:  the 's said been sent in the the first 's office , which basically as a vessels in the . . <SEP>
# | b_prd:  <GO> standard we had been , to of the nation the <NUM> , , , a the , of of said . <SEP>
#
#
# Epoch:  6 | batch:  220 | loss: 2.497
# | tgt:  <GO> his wife , married to moore by a justice of the peace , started planning her dream wedding . <SEP>
# | f_prd:  the decision , who <NUM> be , the state 's the company 's which a in bit . . <SEP>
# | b_prd:  <GO> the <NUM> was , be said , the part of to said and , with the to said . <SEP>
#
#
# Epoch:  6 | batch:  240 | loss: 2.663
# | tgt:  <GO> <quote> if i was diagnosed today with cjd , i would ensure i received this treatment as soon as humanly possible . <SEP>
# | f_prd:  <quote> we it think not with , the , <quote> think be it have <quote> , , <quote> to <quote> it . <SEP>
# | b_prd:  <GO> <quote> <quote> it we is , for said <quote> it to <quote> has is 's him be him is be said . <SEP>
#
#
# Epoch:  7 | batch:  0 | loss: 2.451
# | tgt:  <GO> he praised the work of the rhodes trust , saying that it was a rhodes scholar at oxford who first interested him in politics . <SEP>
# | f_prd:  the also the first of the first chamber , said that the is a technical pro-kremlin in a <NUM> has interested in in the . <SEP>
# | b_prd:  <GO> he of the one of the al said , said said , , a the , at and their their to years in said . <SEP>
#
#
# Epoch:  7 | batch:  20 | loss: 1.969
# | tgt:  <GO> freeman said not having a driver license has been a burden . <SEP>
# | f_prd:  he 's the the the immediate of in been expected year . <SEP>
# | b_prd:  <GO> he is is is a a he have for a said . <SEP>
#
#
# Epoch:  7 | batch:  40 | loss: 2.290
# | tgt:  <GO> in <NUM> , the building 's owners , the port authority of new york and new jersey , issued guidelines to upgrade the fireproofing to a thickness of <NUM> { inches . <SEP>
# | f_prd:  the the , the company , eyes , the company republic to the york stock <NUM> york , birdied the to be the first to the half-century of <NUM> percent est . <SEP>
# | b_prd:  <GO> in <NUM> of the poor 's <NUM> , the the <NUM> in new , of new <NUM> , as , to , the , in a news the <NUM> <NUM> <NUM> . <SEP>
#
#
# Epoch:  7 | batch:  60 | loss: 2.280
# | tgt:  <GO> in vienna , the international atomic energy agency said on monday elbaradei had accepted iran 's invitation , but said no date had yet been set . <SEP>
# | f_prd:  in a , the <NUM>-year-old starts officer court said in the , had not a 's capacity , and he it president was a a . . <SEP>
# | b_prd:  <GO> in <NUM> , the an 's the , said said said who <quote> on nation the said , , <quote> , he not have an said . <SEP>
#
#
# Epoch:  7 | batch:  80 | loss: 1.987
# | tgt:  <GO> the civilian unemployment rate improved marginally last month -- slipping to <NUM> percent -- even as companies slashed payrolls by <NUM> . <SEP>
# | f_prd:  the two unemployment rate improved marginally in month on escaped to <NUM> percent , and in the on payrolls by <NUM> . <SEP>
# | b_prd:  <GO> the statewide unemployment average on <NUM> last percent was <NUM> to <NUM> <NUM> , <NUM> and percent percent percent $ <NUM> . <SEP>
#
#
# Epoch:  7 | batch:  100 | loss: 2.377
# | tgt:  <GO> the bulk of the funds , some $ <NUM> billion , will go for military operations in iraq and afghanistan . <SEP>
# | f_prd:  the company of the united of <NUM> than <NUM> million , compared be from <NUM> operations and the and prevention . <SEP>
# | b_prd:  <GO> the shares of stephen <NUM> , to $ <NUM> <NUM> , to , their for <NUM> in , in <NUM> . <SEP>
#
#
# Epoch:  7 | batch:  120 | loss: 2.026
# | tgt:  <GO> wal-mart shares rose <NUM> cents to close at $ <NUM> on the new york stock exchange . <SEP>
# | f_prd:  shares 's rose <NUM> cents , $ to $ <NUM> in the new york stock exchange . <SEP>
# | b_prd:  <GO> <GO> shares rose <NUM> <NUM> to <NUM> to $ <NUM> on the new york stock <NUM> . <SEP>
#
#
# Epoch:  7 | batch:  140 | loss: 2.501
# | tgt:  <GO> u.s. agriculture secretary ann veneman , who announced tuesdays ban , also said washington would send a technical team to canada to help . <SEP>
# | f_prd:  <quote> secretary secretary donald veneman , who was that office , said said it , be a technical authority to the for the . <SEP>
# | b_prd:  <GO> the chief secretary james said , who said 's said , , of he would is a 's , in , to said . <SEP>
#
#
# Epoch:  7 | batch:  160 | loss: 2.166
# | tgt:  <GO> miodrag zivkovic , of the liberal alliance of montenegro , won <NUM> percent of the vote , while the independent dragan hajdukovic got <NUM> percent . <SEP>
# | f_prd:  <quote> watan , <NUM> the united court , michigan , was a , , the first , which the company shared hajdukovic had a . . <SEP>
# | b_prd:  <GO> b. <NUM> one , the al <NUM> of <NUM> , about <NUM> percent of the <NUM> , , the , , , or <NUM> <NUM> . <SEP>
#
#
# Epoch:  7 | batch:  180 | loss: 2.382
# | tgt:  <GO> the national transportation safety board had subpoenaed him , but he initially ignored the order . <SEP>
# | f_prd:  the company pound officer officer has not the , the the was on the death . <SEP>
# | b_prd:  <GO> the the chief the who had to said , , , who to to said . <SEP>
#
#
# Epoch:  7 | batch:  200 | loss: 2.715
# | tgt:  <GO> general motors corp. posted a record <NUM> percent improvement in <NUM> . <SEP>
# | f_prd:  shares jeffery 's has the <NUM> of percent of in <NUM> . <SEP>
# | b_prd:  <GO> sir average has was the to <NUM> percent <NUM> to <NUM> . <SEP>
#
#
# Epoch:  7 | batch:  220 | loss: 2.168
# | tgt:  <GO> some of the passengers were from benin , guinea and sierra leone . <SEP>
# | f_prd:  the was the first , a the , including and sierra leone . <SEP>
# | b_prd:  <GO> one of the it , at year , rehnquist and hurricane said . <SEP>
#
#
# Epoch:  7 | batch:  240 | loss: 2.471
# | tgt:  <GO> a month ago a military transport plane returned to baghdad when an engine exploded in what officials called a <quote> safety incident . <quote> <SEP>
# | f_prd:  the new ago , year , widow , to be , the disgrace pharmacy in the the could a nyc milestone services . <quote> <SEP>
# | b_prd:  <GO> last <NUM> has the an a be plans to , as a and <quote> that and have in a the the year . <quote> <SEP>
#
#
# Epoch:  8 | batch:  0 | loss: 1.686
# | tgt:  <GO> the largest gains were seen in prices , new orders , inventories and exports . <SEP>
# | f_prd:  the company supplier is found by the , including york , including and sierra . <SEP>
# | b_prd:  <GO> the 's who be said including news the new lawyer , , and said . <SEP>
#
#
# Epoch:  8 | batch:  20 | loss: 2.207
# | tgt:  <GO> the bureau report shows significant increases in uninsured rates occurred among whites , blacks , people <NUM> to <NUM> , and middle- and higher-income earners nationwide . <SEP>
# | f_prd:  the new has killed in miners in mcnabb in ' as two , profile , a , , <NUM> , and yosvani and <NUM> reports and . <SEP>
# | b_prd:  <GO> the the also , been years in <NUM> <NUM> <NUM> at <NUM> , <NUM> <NUM> $ , , <NUM> , and , and eur year <NUM> . <SEP>
#
#
# Epoch:  8 | batch:  40 | loss: 2.030
# | tgt:  <GO> the government shut down in washington , and federal offices were to remain closed yesterday . <SEP>
# | f_prd:  the company , on by <NUM> , including state executive was to be on . . <SEP>
# | b_prd:  <GO> the will was <NUM> in <NUM> , and the it trying and he on said . <SEP>
#
#
# Epoch:  8 | batch:  60 | loss: 1.974
# | tgt:  <GO> that compared with a loss of $ <NUM> million , or $ <NUM> per share in the same period a year earlier . <SEP>
# | f_prd:  he compares with the $ of $ <NUM> million , or <NUM> <NUM> million cent , the same period a year ago . <SEP>
# | b_prd:  <GO> , was for a loss of $ <NUM> <NUM> , at $ cents a <NUM> in the same period a year percent . <SEP>
# Epoch:  8 | batch:  80 | loss: 1.836
# | tgt:  <GO> analysts had expected <NUM> cents a share , according to research firm thomson first call . <SEP>
# | f_prd:  in was reported to cents a share , compared to $ in have quarter call . <SEP>
# | b_prd:  <GO> it was to <NUM> cents per <NUM> , <NUM> the the and thomson to percent . <SEP>
#
#
# Epoch:  8 | batch:  100 | loss: 2.189
# | tgt:  <GO> if the companies won 't , their drugs could be prescribed to medicaid patients only with the state 's say-so . <SEP>
# | f_prd:  the the united , 't be <quote> husband that be short- to be the if to the united 's say-so . <SEP>
# | b_prd:  <GO> <quote> the , robert ago said 's it to be , and have be , of the ashcroft 's statement . <SEP>
#
#
# Epoch:  8 | batch:  120 | loss: 1.930
# | tgt:  <GO> <quote> if the voluntary reliability standards were complied with , we wouldn 't have had a problem . <quote> <SEP>
# | f_prd:  <quote> we the idea reliability standards , not , , <quote> have 't be a a statement . <quote> <SEP>
# | b_prd:  <GO> <quote> <quote> the 's 's , been shut said , we don we , is the said . <quote> <SEP>
#
#
# Epoch:  8 | batch:  140 | loss: 1.818
# | tgt:  <GO> the investigation was closed without charges in <NUM> . <SEP>
# | f_prd:  the broader is found from <NUM> for springdale . <SEP>
# | b_prd:  <GO> the it also <NUM> of <NUM> to <NUM> . <SEP>
#
#
# Epoch:  8 | batch:  160 | loss: 2.060
# | tgt:  <GO> q : can i buy coverage for prescription drugs right away ? <SEP>
# | f_prd:  <quote> with we have 't pay for the drugs in . . <SEP>
# | b_prd:  <GO> said he did to with war of and been war . . <SEP>
#
#
# Epoch:  8 | batch:  180 | loss: 2.041
# | tgt:  <GO> young faces a fine , suspension or being permanently barred from the securities industry . <SEP>
# | f_prd:  <quote> has a similar , shelley with an drugs from from the murder industry . <SEP>
# | b_prd:  <GO> he for a thursday , , as be be comment of the both war . <SEP>
#
#
# Epoch:  8 | batch:  200 | loss: 2.051
# | tgt:  <GO> the equivalent of <NUM> <NUM>-gallon barrels of waste thought to contain transuranic waste are stored underground at hanford . <SEP>
# | f_prd:  the <NUM>-year of <NUM> percent barrels , $ , to be cancer and is plentiful custody and hanford . <SEP>
# | b_prd:  <GO> the shares about <NUM> <NUM> number and been according and with tribal and had for percent at percent . <SEP>
#
#
# Epoch:  8 | batch:  220 | loss: 2.198
# | tgt:  <GO> byrne says he got carried away with powerpoint and just <quote> started making stuff . <quote> <SEP>
# | f_prd:  <quote> said he would not without , an and we parts sensible this this . <quote> <SEP>
# | b_prd:  <GO> he <quote> he be presented were to , , as they to on war . <quote> <SEP>
#
#
# Epoch:  8 | batch:  240 | loss: 2.310
# | tgt:  <GO> the company 's operating loss rose <NUM> percent to $ <NUM> million , from $ <NUM> million a year earlier . <SEP>
# | f_prd:  the institute will customer gauges of to percent , $ <NUM> million , or $ <NUM> billion in year earlier . <SEP>
# | b_prd:  <GO> the germany the 's , or <NUM> , of $ <NUM> percent , to $ <NUM> earlier a year <NUM> . <SEP>
#
#
# Epoch:  9 | batch:  0 | loss: 1.990
# | tgt:  <GO> most times , wholesalers sold the questionable drugs to one of three huge national distributors that supply virtually all drugs in the country . <SEP>
# | f_prd:  u.s. of in including are the questionable 's to the of the of troops products , the of the of in the indian . <SEP>
# | b_prd:  <GO> the however the has perform the that , , one of , and foreign , and , with the <quote> in the statement . <SEP>
#
#
# Epoch:  9 | batch:  20 | loss: 2.031
# | tgt:  <GO> the number of americans considered extremely obese , or at least <NUM> pounds overweight , has quadrupled since the 1980s to a startling <NUM> million , the research shows . <SEP>
# | f_prd:  the company of michigan on after cancer , the <NUM> least <NUM> million and and <NUM> quadrupled as the <NUM> to <NUM> thickness <NUM> million to the company said . <SEP>
# | b_prd:  <GO> the shares 's would to on <NUM> , was at about <NUM> , <NUM> , , , in the , to a $ <NUM> <NUM> , the he said . <SEP>
#
#
# Epoch:  9 | batch:  40 | loss: 1.734
# | tgt:  <GO> <quote> we put the call out , <quote> said the rev. patrick j. mahoney , director of the christian defense coalition . <SEP>
# | f_prd:  <quote> the think the streets , of <quote> the the ftc william halla mahoney , director of the world defense coalition . <SEP>
# | b_prd:  <GO> <quote> we told to thrown said , , , the rev. dr. patrick attorney , some of the 's the statement . <SEP>
#
#
# Epoch:  9 | batch:  60 | loss: 1.952
# | tgt:  <GO> lee told the newspaper that the girl had dragged the food , toys and other things into her mother 's bedroom , where he found her . <SEP>
# | f_prd:  <quote> said the first , the first was been the first , but and other things into the wife 's bedroom , <quote> he said . . <SEP>
# | b_prd:  <GO> he said agriculture said said the who has of the europe , toys and technical seen at his nation the constitution , <quote> has on said . <SEP>
#
#
# Epoch:  9 | batch:  80 | loss: 2.082
# | tgt:  <GO> products featuring vanderpool will be released within five years , he said . <SEP>
# | f_prd:  <quote> has vanderpool will be reached in the years in and said . <SEP>
# | b_prd:  <GO> , san it to be up to two <quote> <quote> he said . <SEP>
#
#
# Epoch:  9 | batch:  100 | loss: 1.945
# | tgt:  <GO> j.d. edwards shareholders will receive <NUM> of a share of peoplesoft for each share of j.d. edwards . <SEP>
# | f_prd:  shares volume shares will receive <NUM> shares the new of error common the share of <NUM> . . <SEP>
# | b_prd:  <GO> water the shareholders will $ <NUM> cents a shares of <NUM> for a <NUM> ( <NUM> percent . <SEP>
#
#
# Epoch:  9 | batch:  120 | loss: 1.887
# | tgt:  <GO> the technology-heavy nasdaq composite index gained <NUM> points , or <NUM> percent , to <NUM> , its highest close in about <NUM> months . <SEP>
# | f_prd:  the dow nasdaq composite index < <NUM> points , or <NUM> percent , to <NUM> , after highest close , <NUM> <NUM> percent . <SEP>
# | b_prd:  <GO> the technology-laced nasdaq composite .spx up <NUM> points , or <NUM> percent , $ percent , its to <NUM> at at <NUM> percent . <SEP>
#
#
# Epoch:  9 | batch:  140 | loss: 1.930
# | tgt:  <GO> the fifth nominee for fiction is scott spencer , for a ship made of paper . <SEP>
# | f_prd:  the ftc opens for the and not as of <quote> the interview of to question . <SEP>
# | b_prd:  <GO> the the spokesman of , , years war , that 's been amounts and war . <SEP>
#
#
# Epoch:  9 | batch:  160 | loss: 1.781
# | tgt:  <GO> the test , in four sections , includes algebra and geometry , along with some questions on probability and statistics . <SEP>
# | f_prd:  the company , which four sections , said algebra and geometry with but with a of on the and statistics . <SEP>
# | b_prd:  <GO> the co based , four <NUM> , at , and companies , , of , , as , and yesterday . <SEP>
#
#
# Epoch:  9 | batch:  180 | loss: 1.902
# | tgt:  <GO> we intend to appeal vigorously and still expect to be vindicated ultimately . <SEP>
# | f_prd:  he believe to be any and have tried him be vindicated ultimately . <SEP>
# | b_prd:  <GO> we plans to as it an would trying to be be iraq . <SEP>
#
#
# Epoch:  9 | batch:  200 | loss: 1.889
# | tgt:  <GO> on thursday , a post article argued that a <NUM>-basis-point cut was most likely . <SEP>
# | f_prd:  he thursday , a cdc article was that neither narrow was was found months . <SEP>
# | b_prd:  <GO> on <NUM> , a 's has said , a they it were were iraq . <SEP>
#
#
# Epoch:  9 | batch:  220 | loss: 1.779
# | tgt:  <GO> ernst & young has denied any wrongdoing and plans to fight the allegations . <SEP>
# | f_prd:  <quote> & young has said that brother , his to be the case . <SEP>
# | b_prd:  <GO> ernst & it have sending of membership been trying to in in comment . <SEP>
#
#
# Epoch:  9 | batch:  240 | loss: 2.253
# | tgt:  <GO> executive recruiters say that finding a seasoned chief merchandising officer will perhaps be the trickiest of all hires because there is such a dearth of good ones . <SEP>
# | f_prd:  <quote> stanley said that neither the seasoned chief executive officer has be be a trickiest of the of to <quote> is no as buyer of public interests . <SEP>
# | b_prd:  <GO> state we said that finding a and chief foreign it would to is the one in that said that it is has a forms for hurricane comment . <SEP>
